# %%
# Import packages. 
import pandas as pd 
import os 

# Excel packages.
from openpyxl import Workbook as wb 
from openpyxl import load_workbook as lwb

# %%
# loaing packages. 
xl = pd.read_excel('extract.xlsx', sheet_name = '196',engine='openpyxl', na_values=['nan'])

# View file
xl
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0          NaN                                                NaN        NaN
# 1          NaN                             CONTAINER 196(2 X40FT)        NaN
# 2         S/N                                         DESCRIPTION       CODE
# 3          NaN                                                NaN        NaN
# 4          NaN                                            DURAVIT        NaN
# ..         ...                                                ...        ...
# 134          1           SHOWER SET CROMA SELECT S/UNICROMA 650MM   26564400
# 135          2  THERMOSTAT CONCEALED SHOWER SELECT 2 OUT LET C...   15763000
# 136          3  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...   27378000
# 137          4  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...   27378000
# 138        NaN                                                NaN        NaN
#
#     Unnamed: 3          Unnamed: 4            Unnamed: 5  Unnamed: 6  \
# 0          NaN                 NaN                   NaN         NaN
# 1          NaN                 NaN                   NaN         NaN
# 2     QUANTITY  UNIT PRICE IN EURO  TOTAL PRICE IN EURO          NaN
# 3          NaN                 NaN                   NaN         NaN
# 4          NaN                 NaN                   NaN         NaN
# ..         ...                 ...                   ...         ...
# 134          5               40.37                201.85         NaN
# 135          4               256.8                1027.2         NaN
# 136          3              232.63                697.89         NaN
# 137          2              232.63                465.26         NaN
# 138        NaN                 NaN                2392.2         NaN
#
#               Unnamed: 7            Unnamed: 8                     Unnamed: 9  \
# 0                    NaN                   NaN                            135
# 1                    550                   NaN                            NaN
# 2    UNIT PRICE IN NAIRA  TOTAL PRICE IN NAIRA                        CLIENT
# 3                    NaN                   NaN                            NaN
# 4                    NaN                   NaN                            NaN
# ..                   ...                   ...                            ...
# 134              22203.5              111017.5                VARIOUS CLIENTS
# 135               141240                564960  REPLACEMENT FOR LENO ADESANYA
# 136             127946.5              383839.5                VARIOUS CLIENTS
# 137             127946.5                255893                VARIOUS CLIENTS
# 138             419336.5               1315710                            NaN
#
#         Unnamed: 10     Unnamed: 11
# 0                37             NaN
# 1               NaN             NaN
# 2    INVOICE NUMBER  INVOICE VALUE
# 3               NaN             NaN
# 4               NaN             NaN
# ..              ...             ...
# 134      6523084637          2392.2
# 135      6523084637             NaN
# 136      6523084637             NaN
# 137      6523084637             NaN
# 138             NaN             NaN
#
# [139 rows x 12 columns]

# %%
xl.fillna('NA')

xl.head()
# Out:
#   Unnamed: 0              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0        NaN                     NaN        NaN        NaN
# 1        NaN  CONTAINER 196(2 X40FT)        NaN        NaN
# 2       S/N              DESCRIPTION       CODE   QUANTITY
# 3        NaN                     NaN        NaN        NaN
# 4        NaN                 DURAVIT        NaN        NaN
#
#            Unnamed: 4            Unnamed: 5  Unnamed: 6           Unnamed: 7  \
# 0                 NaN                   NaN         NaN                  NaN
# 1                 NaN                   NaN         NaN                  550
# 2  UNIT PRICE IN EURO  TOTAL PRICE IN EURO          NaN  UNIT PRICE IN NAIRA
# 3                 NaN                   NaN         NaN                  NaN
# 4                 NaN                   NaN         NaN                  NaN
#
#              Unnamed: 8 Unnamed: 9     Unnamed: 10     Unnamed: 11
# 0                   NaN        135              37             NaN
# 1                   NaN        NaN             NaN             NaN
# 2  TOTAL PRICE IN NAIRA    CLIENT   INVOICE NUMBER  INVOICE VALUE
# 3                   NaN        NaN             NaN             NaN
# 4                   NaN        NaN             NaN             NaN

# %%
code = xl.iloc[1, :].dropna().tolist()

code
# Out:
# ['CONTAINER 196(2 X40FT)', 550]

# %%
# Deleting rows
xl.drop([0,1], axis=0, inplace=True)

# checking file
xl
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 2         S/N                                         DESCRIPTION
# 3          NaN                                                NaN
# 4          NaN                                            DURAVIT
# 5            1     DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL
# 6            2                     DCODE HANDRINSE BASIN/45X34CM
# ..         ...                                                ...
# 134          1           SHOWER SET CROMA SELECT S/UNICROMA 650MM
# 135          2  THERMOSTAT CONCEALED SHOWER SELECT 2 OUT LET C...
# 136          3  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...
# 137          4  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...
# 138        NaN                                                NaN
#
#       Unnamed: 2 Unnamed: 3          Unnamed: 4            Unnamed: 5  \
# 2           CODE   QUANTITY  UNIT PRICE IN EURO  TOTAL PRICE IN EURO
# 3            NaN        NaN                 NaN                   NaN
# 4            NaN        NaN                 NaN                   NaN
# 5    25350900002         60                48.8                  2928
# 6    07054500002         36                24.4                 878.4
# ..           ...        ...                 ...                   ...
# 134     26564400          5               40.37                201.85
# 135     15763000          4               256.8                1027.2
# 136     27378000          3              232.63                697.89
# 137     27378000          2              232.63                465.26
# 138          NaN        NaN                 NaN                2392.2
#
#      Unnamed: 6           Unnamed: 7            Unnamed: 8  \
# 2           NaN  UNIT PRICE IN NAIRA  TOTAL PRICE IN NAIRA
# 3           NaN                  NaN                   NaN
# 4           NaN                  NaN                   NaN
# 5           NaN                26840               1610400
# 6           NaN                13420                483120
# ..          ...                  ...                   ...
# 134         NaN              22203.5              111017.5
# 135         NaN               141240                564960
# 136         NaN             127946.5              383839.5
# 137         NaN             127946.5                255893
# 138         NaN             419336.5               1315710
#
#                         Unnamed: 9     Unnamed: 10     Unnamed: 11
# 2                          CLIENT   INVOICE NUMBER  INVOICE VALUE
# 3                              NaN             NaN             NaN
# 4                              NaN             NaN             NaN
# 5                            STOCK        F7324998          6230.4
# 6                            STOCK        F7324998             NaN
# ..                             ...             ...             ...
# 134                VARIOUS CLIENTS      6523084637          2392.2
# 135  REPLACEMENT FOR LENO ADESANYA      6523084637             NaN
# 136                VARIOUS CLIENTS      6523084637             NaN
# 137                VARIOUS CLIENTS      6523084637             NaN
# 138                            NaN             NaN             NaN
#
# [137 rows x 12 columns]

# %%
# converting first row to header. 
xl.columns = ['S/N','DESCRIPTION','CODE','QUANTITY','UNIT PRICE IN EURO','TOTAL PRICE IN EURO ','EXCHANGE_RATE',
              'UNIT PRICE IN NAIRA','TOTAL PRICE IN NAIRA','CLIENT ','INVOICE NUMBER','INVOICE VALUE']

# Drop first row
xl.drop([2], axis= 0, inplace = True)
xl.reset_index()

# Checking values.
xl
# Out:
#      S/N                                        DESCRIPTION         CODE  \
# 3    NaN                                                NaN          NaN
# 4    NaN                                            DURAVIT          NaN
# 5      1     DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL  25350900002
# 6      2                     DCODE HANDRINSE BASIN/45X34CM   07054500002
# 7      3  DCODE SIPHON COVER FOR BASIN 070545/FIXINGS IN...  08571700002
# ..   ...                                                ...          ...
# 134    1           SHOWER SET CROMA SELECT S/UNICROMA 650MM     26564400
# 135    2  THERMOSTAT CONCEALED SHOWER SELECT 2 OUT LET C...     15763000
# 136    3  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000
# 137    4  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000
# 138  NaN                                                NaN          NaN
#
#     QUANTITY UNIT PRICE IN EURO TOTAL PRICE IN EURO   EXCHANGE_RATE  \
# 3        NaN                NaN                  NaN            NaN
# 4        NaN                NaN                  NaN            NaN
# 5         60               48.8                 2928            NaN
# 6         36               24.4                878.4            NaN
# 7         36               29.2               1051.2            NaN
# ..       ...                ...                  ...            ...
# 134        5              40.37               201.85            NaN
# 135        4              256.8               1027.2            NaN
# 136        3             232.63               697.89            NaN
# 137        2             232.63               465.26            NaN
# 138      NaN                NaN               2392.2            NaN
#
#     UNIT PRICE IN NAIRA TOTAL PRICE IN NAIRA                        CLIENT   \
# 3                   NaN                  NaN                            NaN
# 4                   NaN                  NaN                            NaN
# 5                 26840              1610400                          STOCK
# 6                 13420               483120                          STOCK
# 7                 16060               578160                          STOCK
# ..                  ...                  ...                            ...
# 134             22203.5             111017.5                VARIOUS CLIENTS
# 135              141240               564960  REPLACEMENT FOR LENO ADESANYA
# 136            127946.5             383839.5                VARIOUS CLIENTS
# 137            127946.5               255893                VARIOUS CLIENTS
# 138            419336.5              1315710                            NaN
#
#     INVOICE NUMBER INVOICE VALUE
# 3              NaN           NaN
# 4              NaN           NaN
# 5         F7324998        6230.4
# 6         F7324998           NaN
# 7         F7324998           NaN
# ..             ...           ...
# 134     6523084637        2392.2
# 135     6523084637           NaN
# 136     6523084637           NaN
# 137     6523084637           NaN
# 138            NaN           NaN
#
# [136 rows x 12 columns]

# %%
# Creating columns.
xl['SUPPLIER_NAME'] = ' '
xl['CONTAINER_CODE'] = code[0]

# Checking file
xl
# Out:
#      S/N                                        DESCRIPTION         CODE  \
# 3    NaN                                                NaN          NaN
# 4    NaN                                            DURAVIT          NaN
# 5      1     DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL  25350900002
# 6      2                     DCODE HANDRINSE BASIN/45X34CM   07054500002
# 7      3  DCODE SIPHON COVER FOR BASIN 070545/FIXINGS IN...  08571700002
# ..   ...                                                ...          ...
# 134    1           SHOWER SET CROMA SELECT S/UNICROMA 650MM     26564400
# 135    2  THERMOSTAT CONCEALED SHOWER SELECT 2 OUT LET C...     15763000
# 136    3  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000
# 137    4  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000
# 138  NaN                                                NaN          NaN
#
#     QUANTITY UNIT PRICE IN EURO TOTAL PRICE IN EURO   EXCHANGE_RATE  \
# 3        NaN                NaN                  NaN            NaN
# 4        NaN                NaN                  NaN            NaN
# 5         60               48.8                 2928            NaN
# 6         36               24.4                878.4            NaN
# 7         36               29.2               1051.2            NaN
# ..       ...                ...                  ...            ...
# 134        5              40.37               201.85            NaN
# 135        4              256.8               1027.2            NaN
# 136        3             232.63               697.89            NaN
# 137        2             232.63               465.26            NaN
# 138      NaN                NaN               2392.2            NaN
#
#     UNIT PRICE IN NAIRA TOTAL PRICE IN NAIRA                        CLIENT   \
# 3                   NaN                  NaN                            NaN
# 4                   NaN                  NaN                            NaN
# 5                 26840              1610400                          STOCK
# 6                 13420               483120                          STOCK
# 7                 16060               578160                          STOCK
# ..                  ...                  ...                            ...
# 134             22203.5             111017.5                VARIOUS CLIENTS
# 135              141240               564960  REPLACEMENT FOR LENO ADESANYA
# 136            127946.5             383839.5                VARIOUS CLIENTS
# 137            127946.5               255893                VARIOUS CLIENTS
# 138            419336.5              1315710                            NaN
#
#     INVOICE NUMBER INVOICE VALUE SUPPLIER_NAME          CONTAINER_CODE
# 3              NaN           NaN                CONTAINER 196(2 X40FT)
# 4              NaN           NaN                CONTAINER 196(2 X40FT)
# 5         F7324998        6230.4                CONTAINER 196(2 X40FT)
# 6         F7324998           NaN                CONTAINER 196(2 X40FT)
# 7         F7324998           NaN                CONTAINER 196(2 X40FT)
# ..             ...           ...           ...                     ...
# 134     6523084637        2392.2                CONTAINER 196(2 X40FT)
# 135     6523084637           NaN                CONTAINER 196(2 X40FT)
# 136     6523084637           NaN                CONTAINER 196(2 X40FT)
# 137     6523084637           NaN                CONTAINER 196(2 X40FT)
# 138            NaN           NaN                CONTAINER 196(2 X40FT)
#
# [136 rows x 14 columns]

# %%
# Reordering columns 
xl = xl.loc[:, ['S/N', 'CONTAINER_CODE', 'SUPPLIER_NAME','DESCRIPTION', 'CODE', 'QUANTITY', 
     'UNIT PRICE IN EURO','TOTAL PRICE IN EURO ', 'EXCHANGE_RATE', 'UNIT PRICE IN NAIRA',
     'TOTAL PRICE IN NAIRA', 'CLIENT ', 'INVOICE NUMBER', 'INVOICE VALUE']]

# Checking columns order
xl.columns
# Out:
# Index(['S/N', 'CONTAINER_CODE', 'SUPPLIER_NAME', 'DESCRIPTION', 'CODE',
#        'QUANTITY', 'UNIT PRICE IN EURO', 'TOTAL PRICE IN EURO ',
#        'EXCHANGE_RATE', 'UNIT PRICE IN NAIRA', 'TOTAL PRICE IN NAIRA',
#        'CLIENT ', 'INVOICE NUMBER', 'INVOICE VALUE'],
#       dtype='object')

# %%
# Drop columns that aren't needed
del xl['S/N']
del xl['INVOICE VALUE']

# Check 
xl
# Out:
#              CONTAINER_CODE SUPPLIER_NAME  \
# 3    CONTAINER 196(2 X40FT)
# 4    CONTAINER 196(2 X40FT)
# 5    CONTAINER 196(2 X40FT)
# 6    CONTAINER 196(2 X40FT)
# 7    CONTAINER 196(2 X40FT)
# ..                      ...           ...
# 134  CONTAINER 196(2 X40FT)
# 135  CONTAINER 196(2 X40FT)
# 136  CONTAINER 196(2 X40FT)
# 137  CONTAINER 196(2 X40FT)
# 138  CONTAINER 196(2 X40FT)
#
#                                            DESCRIPTION         CODE QUANTITY  \
# 3                                                  NaN          NaN      NaN
# 4                                              DURAVIT          NaN      NaN
# 5       DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL  25350900002       60
# 6                       DCODE HANDRINSE BASIN/45X34CM   07054500002       36
# 7    DCODE SIPHON COVER FOR BASIN 070545/FIXINGS IN...  08571700002       36
# ..                                                 ...          ...      ...
# 134           SHOWER SET CROMA SELECT S/UNICROMA 650MM     26564400        5
# 135  THERMOSTAT CONCEALED SHOWER SELECT 2 OUT LET C...     15763000        4
# 136  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000        3
# 137  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000        2
# 138                                                NaN          NaN      NaN
#
#     UNIT PRICE IN EURO TOTAL PRICE IN EURO   EXCHANGE_RATE  \
# 3                  NaN                  NaN            NaN
# 4                  NaN                  NaN            NaN
# 5                 48.8                 2928            NaN
# 6                 24.4                878.4            NaN
# 7                 29.2               1051.2            NaN
# ..                 ...                  ...            ...
# 134              40.37               201.85            NaN
# 135              256.8               1027.2            NaN
# 136             232.63               697.89            NaN
# 137             232.63               465.26            NaN
# 138                NaN               2392.2            NaN
#
#     UNIT PRICE IN NAIRA TOTAL PRICE IN NAIRA                        CLIENT   \
# 3                   NaN                  NaN                            NaN
# 4                   NaN                  NaN                            NaN
# 5                 26840              1610400                          STOCK
# 6                 13420               483120                          STOCK
# 7                 16060               578160                          STOCK
# ..                  ...                  ...                            ...
# 134             22203.5             111017.5                VARIOUS CLIENTS
# 135              141240               564960  REPLACEMENT FOR LENO ADESANYA
# 136            127946.5             383839.5                VARIOUS CLIENTS
# 137            127946.5               255893                VARIOUS CLIENTS
# 138            419336.5              1315710                            NaN
#
#     INVOICE NUMBER
# 3              NaN
# 4              NaN
# 5         F7324998
# 6         F7324998
# 7         F7324998
# ..             ...
# 134     6523084637
# 135     6523084637
# 136     6523084637
# 137     6523084637
# 138            NaN
#
# [136 rows x 12 columns]

# %%
xl
# Out:
#              CONTAINER_CODE SUPPLIER_NAME  \
# 3    CONTAINER 196(2 X40FT)
# 4    CONTAINER 196(2 X40FT)
# 5    CONTAINER 196(2 X40FT)
# 6    CONTAINER 196(2 X40FT)
# 7    CONTAINER 196(2 X40FT)
# ..                      ...           ...
# 134  CONTAINER 196(2 X40FT)
# 135  CONTAINER 196(2 X40FT)
# 136  CONTAINER 196(2 X40FT)
# 137  CONTAINER 196(2 X40FT)
# 138  CONTAINER 196(2 X40FT)
#
#                                            DESCRIPTION         CODE QUANTITY  \
# 3                                                  NaN          NaN      NaN
# 4                                              DURAVIT          NaN      NaN
# 5       DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL  25350900002       60
# 6                       DCODE HANDRINSE BASIN/45X34CM   07054500002       36
# 7    DCODE SIPHON COVER FOR BASIN 070545/FIXINGS IN...  08571700002       36
# ..                                                 ...          ...      ...
# 134           SHOWER SET CROMA SELECT S/UNICROMA 650MM     26564400        5
# 135  THERMOSTAT CONCEALED SHOWER SELECT 2 OUT LET C...     15763000        4
# 136  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000        3
# 137  OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300...     27378000        2
# 138                                                NaN          NaN      NaN
#
#     UNIT PRICE IN EURO TOTAL PRICE IN EURO   EXCHANGE_RATE  \
# 3                  NaN                  NaN            NaN
# 4                  NaN                  NaN            NaN
# 5                 48.8                 2928            NaN
# 6                 24.4                878.4            NaN
# 7                 29.2               1051.2            NaN
# ..                 ...                  ...            ...
# 134              40.37               201.85            NaN
# 135              256.8               1027.2            NaN
# 136             232.63               697.89            NaN
# 137             232.63               465.26            NaN
# 138                NaN               2392.2            NaN
#
#     UNIT PRICE IN NAIRA TOTAL PRICE IN NAIRA                        CLIENT   \
# 3                   NaN                  NaN                            NaN
# 4                   NaN                  NaN                            NaN
# 5                 26840              1610400                          STOCK
# 6                 13420               483120                          STOCK
# 7                 16060               578160                          STOCK
# ..                  ...                  ...                            ...
# 134             22203.5             111017.5                VARIOUS CLIENTS
# 135              141240               564960  REPLACEMENT FOR LENO ADESANYA
# 136            127946.5             383839.5                VARIOUS CLIENTS
# 137            127946.5               255893                VARIOUS CLIENTS
# 138            419336.5              1315710                            NaN
#
#     INVOICE NUMBER
# 3              NaN
# 4              NaN
# 5         F7324998
# 6         F7324998
# 7         F7324998
# ..             ...
# 134     6523084637
# 135     6523084637
# 136     6523084637
# 137     6523084637
# 138            NaN
#
# [136 rows x 12 columns]

# %%
# Supplier and item code list 
supplier = xl['DESCRIPTION'].fillna('re').to_list()
item_code = xl['CODE'].fillna('re').to_list()

# Check
supplier, item_code
# Out:
# (['re',
#   'DURAVIT',
#   'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#   'DCODE HANDRINSE BASIN/45X34CM ',
#   'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#   'DCODE WASHBASIN/55X42CM ',
#   'DCODE SIPHON COVER/FIXINGS INCLUDED',
#   'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#   'DURASTYLE SEAT & COVER SOFTCLOSE AUTOMATIC CLOSURE/REMOVABLE',
#   'STOOL FOR ST TROP WHITE',
#   're',
#   'COLOMBO',
#   'LAND ROBE HOOK',
#   'NORDIC SOAP DISH ( DOUBLE TAPE)',
#   'NORDIC GLASS HOLDER',
#   'NORDIC  WALL HUNG TOILET BURSH ( DOUBLE TAPE)',
#   'NORDIC TISSUE PAPER ( DOUBLE TAPE)',
#   'NORDIC TOWEL HOLDER 54CM ( DOUBLE TAPE)',
#   'BASIC SOAP DISPENSER',
#   'NORDIC BIG ROBE HOOK ( DOUBLE TAPE)',
#   'BASIC SOAP DISH CROME - NARTUAR ACID GLASS',
#   'BASIC GLASS HOLDER NATURAL ACID GLASS',
#   'BASIC PAPER HOLDER',
#   'BASIC TOWEL HOLDER 60CM',
#   'BASIC ROBE HOOK BIG',
#   'BASIC GLASS HOLDER NATURAL ACID GLASS',
#   'BASIC PAPER HOLDER',
#   'BASIC TOWEL HOLDER 60CM',
#   'BASIC ROBE HOOK BIG',
#   'BASIC SOAP DISPENSER',
#   're',
#   're',
#   'OIKOS',
#   'SYNUA FLUSH WITH WALL INTERNAL 1500X2750',
#   'PROFILE TECHNO T02 AN',
#   'ALUMINIUM SCREW',
#   're',
#   'LAUFEN ',
#   'CUBE VANITY UNIT WITH WASHBASIN 65CM/WHITE',
#   'MIRROR 45X81 CM WITH OUT LIGHT',
#   'FLORA KIDS WORM MIRROR SEGMENT- BODY GREEN ',
#   'PRO RIMLESS WALLHUNG WC PAN WITH NICHES/WHITE',
#   'PRO RIMLESS WALLHUNG WC PAN WITH NICHES/WHITE',
#   'PRO S RIMLESS WALLHUNG WC PAN /WHITE',
#   'PALACE SEAT AND COVER',
#   'PRO S SEAT AND COVER ',
#   'PRO A SLIM BASIC SEAT AND COVER',
#   'PRO A SLIM BASIC SEAT AND COVER',
#   'TIGO TALL CABINET /4 GLASS SHELF /2 DOOR/LEFT/GREEN',
#   'LYRA PLUS WALLHUNG WC PAN',
#   'LYRA PLUS WALLHUNG WC PAN',
#   'LYRA PLUS SEAT & COVER (DUROPLAST) FOR WALLHUNG WC',
#   'LYRA PLUS SEAT & COVER FOR WALL HUNG WC PAN',
#   'LYRA PLUS SEAT & COVER FOR WALL HUNG WC PAN',
#   'LYRAPLUS WASHBASIN/60X49CM',
#   'LYRAPLUS WASHBASIN/55X45CM',
#   'LYRAPLUS WASHBASIN/50X41CM',
#   'LYRA PLUS PEDESTAL FOR WASH BASIN ',
#   'NEW PRO S SIPHON COVER FOR WASH BASIN 1096.2/3',
#   'LAUFEN OVERFLOW SYSTEM WITH WATER INLET',
#   'NEW PRO S WASH BASIN 60X46.5CM ',
#   'PALACE WASHBASIN 60X48CM',
#   'FLORAKIDS WALL HUNG WC PAN',
#   'PRO S VANITY PACK ONE DRAWER BASIN(60X50CM)WHITE G',
#   're',
#   're',
#   'NOBILLIA',
#   'NOBILIA - 312 FOCUS - FITTED KITCHEN UNITS ',
#   'NOBILIA - KITCHEN SINKS',
#   'NOBILIA - BUILT IN - BAKING OVEN ',
#   'NOBILIA - BUILT IN - MICROWAVE OVENS',
#   'NOBILIA - WALL MOUNTED COOKER HOOD',
#   'NOBILIA - DISH WASHING MACHINE',
#   'NOBILIA - PLASTIC RUBBISH BIN  ',
#   'NOBILIA - GAS HOBS  ',
#   'NOBILIA - 312 FOCUS - FITTED KITCHEN UNITS ',
#   'NOBILIA - REFRIDGERATOR BUILDING -IN TYPE',
#   'NOBILIA - DISH WASHING MACHINE',
#   'NOBILIA - PLASTIC RUBBISH BIN  ',
#   're',
#   'WUDUMATE',
#   'WUDUMATE CLASSIC(WHITE) INCLUDING PILLAR TAPS/WASTE AND FIXING',
#   'WUDUMATE COMPACT IN ACRYLIC(WHITE)INCLUDING STOOL, MANUAL LEVER TAP&WASTE',
#   'WUDUMATE COMPACT IN ACRYLIC(WHITE)INCLUDING STOOL, MANUAL LEVER TAP&WASTE',
#   're',
#   'TEUCO',
#   'TEUCO DOUBLE SHOWER SAUNA AND MULTIFUNCTIONS CLEAR PANEL IN GLASS VERSION',
#   'TEUCO THERMOSTATIC MIXER',
#   'TEUCO BATHTUB PANEL 3 SIDES TURNED 180',
#   'TEUCO RIM MOUNTED 4 HOLE BATH TAP SET WITH HANDSHOWER',
#   're',
#   'REMER',
#   'REMER SET COMPOSED BY SHUT-OFF HANDSHOWER',
#   'REMER MIXER WASH-BASIN IN BATH SHOWER',
#   'REMER WINNER BUILT-IN-BATH SHOWER',
#   're',
#   'GEDY',
#   'REPALCEMENT MIRROR FOR 2581',
#   're',
#   're',
#   'MIRAGE',
#   'JW 06 LUC SQ 60 60X60X10',
#   're',
#   're',
#   'CERAMICHE SETTECENTO VALTRESINARO',
#   'ANGOLO CLASSIC A BIANCO 25.5X78',
#   'ANGOLO CLASSIC B BIANCO 25.5X78',
#   'FASCIA CLASSIC BIANCO 25.5X78',
#   'ANGOLO BOISERIE CLASSIC BIANCO 25.5X78',
#   'BOISERE CLASSIC BIANCO 25.5X78',
#   'ZOCCOLO CLASSIC BIANCO 19.9X25.5',
#   'VINTAGE BIANCO GRIP 47.8X47.8 RETTIFICATO',
#   're',
#   'DISCOUNT',
#   'PAID',
#   're',
#   'TYLO',
#   'STEAM 18VA 230/400V',
#   'CONTROL PANEL H1',
#   'swidish krona to usd',
#   're',
#   'LIEBHERE-EXPORT',
#   'REFRIDGERATOR',
#   'REFRIDGERATOR/FREEZER',
#   're',
#   're',
#   'PONTE GIULIO',
#   'SINGLE LEVER MIXER MULTICOLOR',
#   're',
#   're',
#   'HANSGROHE',
#   'SHOWER SET CROMA SELECT S/UNICROMA 650MM',
#   'THERMOSTAT CONCEALED SHOWER SELECT 2 OUT LET CHROME',
#   'OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300MM SHOWER ARM',
#   'OVERHEAD SHOWER RADIANCE SELECT S 300 2JET 300MM SHOWER ARM',
#   're'],
#  ['re',
#   're',
#   25350900002,
#   '07054500002',
#   '08571700002',
#   23105500002,
#   '08571800002',
#   2536090000,
#   '0063790000',
#   7918460000,
#   're',
#   're',
#   'CB CD67',
#   'CB B5201',
#   'CB B5202',
#   'CB B5207',
#   'CB B5208',
#   'CB B5210',
#   'CB B9332',
#   'CB EB27',
#   'CB B2701',
#   'CB B2702',
#   'CB B2708',
#   'CB B2711',
#   'CB B2727',
#   'CB B2702',
#   'CB B2708',
#   'CB B2711',
#   'CB B2727',
#   'CB B9332',
#   're',
#   're',
#   're',
#   1606802,
#   'SPARE',
#   'SPARE',
#   're',
#   're',
#   'JK 5360.1.300',
#   'JK 5570.1.144',
#   'LF 6161.2.472',
#   'LF 2096.4.000',
#   'LF 2096.6.000',
#   'LF 2096.2.000',
#   'LF 9170.1.300',
#   'LF 9196.1.000',
#   'LF 9496.6.000',
#   'LF 9496.6.000',
#   'JK 5526.3.021',
#   'JK 2338.0.000',
#   'JK 2338.0.000',
#   'JK 9338.4.300',
#   'JK 9338.7.000',
#   'JK 9338.5.300',
#   'JK 1438.3.000',
#   'JK 1438.2.104',
#   'JK 1438.1.104',
#   'JK 1939.1.000',
#   'LF 1996.3.000',
#   'LF 9511.1.004',
#   'LF 1096.3.104',
#   'LF 1070.2.104',
#   'LF 2003.1.000',
#   'LF 6096.1.475',
#   're',
#   're',
#   're',
#   94034010,
#   73241000,
#   85166080,
#   85165000,
#   84146000,
#   84221100,
#   39269050,
#   85166050,
#   94034010,
#   84182159,
#   84221100,
#   73239900,
#   're',
#   're',
#   'WM CLAS-PL',
#   'WM COM-A-MLP',
#   'WM COM-A-MLP',
#   're',
#   're',
#   'L07JS26C',
#   'R192',
#   '254-P69',
#   'RS05',
#   're',
#   're',
#   'RM 332332OL',
#   'RM F103SO',
#   'RM W09',
#   're',
#   're',
#   'GD 005002500',
#   're',
#   're',
#   're',
#   'MG JW06',
#   're',
#   're',
#   're',
#   110052,
#   110053,
#   110054,
#   110055,
#   110056,
#   110062,
#   165701,
#   're',
#   're',
#   're',
#   're',
#   're',
#   66205020,
#   72001020,
#   're',
#   're',
#   're',
#   'IK 3510',
#   'IGN 3556',
#   're',
#   're',
#   're',
#   'H50GBS21',
#   're',
#   're',
#   're',
#   26564400,
#   15763000,
#   27378000,
#   27378000,
#   're'])

# %%
supplier_name = [0]
for i in len(supplier):
    if supplier[i] != 're' and item_code[i] == 're':
        print(i)
    else:
        print(pre)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 2>()
#       1 supplier_name = [0]
# ----> 2 for i in len(supplier):
#       3     if supplier != 're' and item_code == 're':
#       4         print(i)
#
# TypeError: 'int' object is not iterable

# %%
supplier_name
# Out:
# ['re',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  're',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DURAVIT D-CODE  WALL MOUNTED WC WASHDOWN MODEL',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE HANDRINSE BASIN/45X34CM ',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER FOR BASIN 070545/FIXINGS INCLUDED',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE WASHBASIN/55X42CM ',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DCODE SIPHON COVER/FIXINGS INCLUDED',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  'DURASTYLE WALL HUNG WC WASH DOWN MODEL',
#  ...]
