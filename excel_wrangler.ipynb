# %%
# Import packages. 
import pandas as pd 
import os 

# Excel packages.
from openpyxl import Workbook as wb 
from openpyxl import load_workbook as lwb

# %%
# loaing packages. 
xl = pd.read_excel('extract_2022-11.xlsx', sheet_name = '205',engine='openpyxl', na_values=['nan'])

# View file
xl
# Out:
#     Unnamed: 0                             Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 0          NaN                                    NaN          NaN        NaN
# 1          NaN                 CONTAINER 205(1 X40FT)          NaN        NaN
# 2         S/N                             DESCRIPTION         CODE   QUANTITY
# 3          NaN                                    NaN          NaN        NaN
# 4          NaN                             SAY EXPORT          NaN        NaN
# ..         ...                                    ...          ...        ...
# 187        NaN                                    NaN          NaN        NaN
# 188        NaN                                    NaN          NaN        NaN
# 189        NaN                                NOBILIA          NaN        NaN
# 190        NaN  FITTED KITCHEN UNITS/193 ALPINE WHITE  NB 21298848          1
# 191        NaN                                    NaN          NaN        NaN
#
#              Unnamed: 4            Unnamed: 5                 EURO  \
# 0                   NaN                   NaN                  USD
# 1                   NaN                   NaN                  NaN
# 2    UNIT PRICE IN EURO  TOTAL PRICE IN EURO   UNIT PRICE IN NAIRA
# 3                   NaN                   NaN                  NaN
# 4                   USD                   NaN                  NaN
# ..                  ...                   ...                  ...
# 187                 NaN                  5586                  NaN
# 188                 NaN                     0                  NaN
# 189                 NaN                     0                  NaN
# 190            12056.88              12056.88        5177935.62792
# 191                 NaN                     0                  NaN
#
#        429.45900000000006  Unnamed: 8      Unnamed: 9     Unnamed: 10  \
# 0                     365         135              37             NaN
# 1                       0         NaN             NaN             NaN
# 2    TOTAL PRICE IN NAIRA     CLIENT   INVOICE NUMBER  INVOICE VALUE
# 3                     NaN         NaN             NaN             NaN
# 4                     NaN         NaN             NaN             NaN
# ..                    ...         ...             ...             ...
# 187           2398957.974         NaN             NaN             NaN
# 188                   NaN         NaN             NaN             NaN
# 189                   NaN         NaN             NaN             NaN
# 190         5177935.62792  TUNNEL END  RG2193315-0011        12056.88
# 191                   NaN         NaN             NaN             NaN
#
#      Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 187          NaN          NaN          NaN          NaN          NaN
# 188          NaN          NaN          NaN          NaN          NaN
# 189          NaN          NaN          NaN          NaN          NaN
# 190          NaN          NaN          NaN          NaN          NaN
# 191          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 16
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 187          NaN
# 188          NaN
# 189          NaN
# 190          NaN
# 191          NaN
#
# [192 rows x 17 columns]

# %%
c_list = []

for i in range(4): 
    c = xl.iloc[i, :].dropna().to_list()
    c_list.append(c)

for j in range(len(c_list)): 
    if len(c_list[j])>=1 and c_list[j][0][:3] == 'CON':
        code = c_list[j][0]
        code_idx = j
        header_idx = j + 1
        break

code,code_idx,header_idx
# Out:
# ('CONTAINER 200(1 X40FT)', 1, 2)

# %%
# Column Header. 
columns = xl.iloc[header_idx,:].to_list()

columns
# Out:
# ['S/N ',
#  'DESCRIPTION',
#  'CODE',
#  'QUANTITY',
#  nan,
#  'UNIT PRICE IN EURO',
#  'TOTAL PRICE IN EURO ',
#  'UNIT PRICE IN NAIRA',
#  'TOTAL PRICE IN NAIRA',
#  'UNIT PRICE (NAIRA)',
#  'TOTAL (NAIRA)',
#  'CLIENT ',
#  'INVOICE NUMBER',
#  'INVOICE VALUE ',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
# converting first row to header. 
xl.columns = columns

# Deleting rows
xl.drop([i for i in range(header_idx+1)], axis=0, inplace=True)

# Reset_index
xl.reset_index(drop = True)

# Checking values.
xl
# Out:
#     S/N                                         DESCRIPTION           CODE  \
# 3    NaN                                                NaN            NaN
# 4    NaN                                                ODF            NaN
# 5      1                      ELECTRICAL TOWEL DRYER 3 BARS      OD 762 01
# 6    NaN                                              TOTAL            NaN
# 7    NaN                                                NaN            NaN
# ..   ...                                                ...            ...
# 218   51  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 219   52  FLORA KIDS WORM MIRROR SEGMENT-BODY GREEN /32X...  LF 6161.2.472
# 220   53    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 221   54    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 222  NaN                                                NaN            NaN
#
#     QUANTITY  NaN UNIT PRICE IN EURO TOTAL PRICE IN EURO  UNIT PRICE IN NAIRA  \
# 3        NaN  NaN                NaN                  NaN                 NaN
# 4        NaN  NaN                NaN                  NaN                 NaN
# 5          2  NaN             450.47               900.94            175683.3
# 6        NaN  NaN                NaN               900.94                 NaN
# 7        NaN  NaN                NaN                  NaN                 NaN
# ..       ...  ...                ...                  ...                 ...
# 218        4  NaN             100.88               403.52                 NaN
# 219       10  NaN               84.4                  844                 NaN
# 220        1  NaN              536.7                536.7                 NaN
# 221        1  NaN              536.7                536.7                 NaN
# 222      NaN  NaN                NaN             17285.68                 NaN
#
#     TOTAL PRICE IN NAIRA UNIT PRICE (NAIRA)  ... INVOICE VALUE   NaN  NaN  \
# 3                    NaN                NaN  ...            NaN  NaN  NaN
# 4                    NaN                NaN  ...            NaN  NaN  NaN
# 5               351366.6      189196.679248  ...         900.94  NaN  NaN
# 6                    NaN                NaN  ...            NaN  NaN  NaN
# 7                    NaN                NaN  ...            NaN  NaN  NaN
# ..                   ...                ...  ...            ...  ...  ...
# 218                  NaN       42369.438592  ...            NaN  NaN  NaN
# 219                  NaN        35447.86496  ...            NaN  NaN  NaN
# 220                  NaN       225413.14128  ...            NaN  NaN  NaN
# 221                  NaN       225413.14128  ...            NaN  NaN  NaN
# 222                  NaN                NaN  ...            NaN  NaN  NaN
#
#      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..   ...  ...  ...  ...  ...  ...  ...
# 218  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 219  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 220  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 221  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 222  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [220 rows x 23 columns]

# %%
# Creating columns.
xl['CONTAINER_CODE'] = code
xl['SUPPLIER_NAME'] = ' '

# Checking file
xl
# Out:
#     S/N                                         DESCRIPTION           CODE  \
# 3    NaN                                                NaN            NaN
# 4    NaN                                                ODF            NaN
# 5      1                      ELECTRICAL TOWEL DRYER 3 BARS      OD 762 01
# 6    NaN                                              TOTAL            NaN
# 7    NaN                                                NaN            NaN
# ..   ...                                                ...            ...
# 218   51  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 219   52  FLORA KIDS WORM MIRROR SEGMENT-BODY GREEN /32X...  LF 6161.2.472
# 220   53    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 221   54    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 222  NaN                                                NaN            NaN
#
#     QUANTITY  NaN UNIT PRICE IN EURO TOTAL PRICE IN EURO  UNIT PRICE IN NAIRA  \
# 3        NaN  NaN                NaN                  NaN                 NaN
# 4        NaN  NaN                NaN                  NaN                 NaN
# 5          2  NaN             450.47               900.94            175683.3
# 6        NaN  NaN                NaN               900.94                 NaN
# 7        NaN  NaN                NaN                  NaN                 NaN
# ..       ...  ...                ...                  ...                 ...
# 218        4  NaN             100.88               403.52                 NaN
# 219       10  NaN               84.4                  844                 NaN
# 220        1  NaN              536.7                536.7                 NaN
# 221        1  NaN              536.7                536.7                 NaN
# 222      NaN  NaN                NaN             17285.68                 NaN
#
#     TOTAL PRICE IN NAIRA UNIT PRICE (NAIRA)  ...  NaN  NaN  NaN  NaN  NaN  \
# 3                    NaN                NaN  ...  NaN  NaN  NaN  NaN  NaN
# 4                    NaN                NaN  ...  NaN  NaN  NaN  NaN  NaN
# 5               351366.6      189196.679248  ...  NaN  NaN  NaN  NaN  NaN
# 6                    NaN                NaN  ...  NaN  NaN  NaN  NaN  NaN
# 7                    NaN                NaN  ...  NaN  NaN  NaN  NaN  NaN
# ..                   ...                ...  ...  ...  ...  ...  ...  ...
# 218                  NaN       42369.438592  ...  NaN  NaN  NaN  NaN  NaN
# 219                  NaN        35447.86496  ...  NaN  NaN  NaN  NaN  NaN
# 220                  NaN       225413.14128  ...  NaN  NaN  NaN  NaN  NaN
# 221                  NaN       225413.14128  ...  NaN  NaN  NaN  NaN  NaN
# 222                  NaN                NaN  ...  NaN  NaN  NaN  NaN  NaN
#
#      NaN  NaN  NaN          CONTAINER_CODE  SUPPLIER_NAME
# 3    NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 4    NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 5    NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 6    NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 7    NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# ..   ...  ...  ...                     ...            ...
# 218  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 219  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 220  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 221  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 222  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
#
# [220 rows x 25 columns]

# %%
# Drop columns that aren't needed
del xl[xl.columns[0]]

# Check 
xl
# Out:
#                                            DESCRIPTION           CODE  \
# 3                                                  NaN            NaN
# 4                                                  ODF            NaN
# 5                        ELECTRICAL TOWEL DRYER 3 BARS      OD 762 01
# 6                                                TOTAL            NaN
# 7                                                  NaN            NaN
# ..                                                 ...            ...
# 218  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 219  FLORA KIDS WORM MIRROR SEGMENT-BODY GREEN /32X...  LF 6161.2.472
# 220    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 221    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 222                                                NaN            NaN
#
#     QUANTITY  NaN UNIT PRICE IN EURO TOTAL PRICE IN EURO  UNIT PRICE IN NAIRA  \
# 3        NaN  NaN                NaN                  NaN                 NaN
# 4        NaN  NaN                NaN                  NaN                 NaN
# 5          2  NaN             450.47               900.94            175683.3
# 6        NaN  NaN                NaN               900.94                 NaN
# 7        NaN  NaN                NaN                  NaN                 NaN
# ..       ...  ...                ...                  ...                 ...
# 218        4  NaN             100.88               403.52                 NaN
# 219       10  NaN               84.4                  844                 NaN
# 220        1  NaN              536.7                536.7                 NaN
# 221        1  NaN              536.7                536.7                 NaN
# 222      NaN  NaN                NaN             17285.68                 NaN
#
#     TOTAL PRICE IN NAIRA UNIT PRICE (NAIRA)   TOTAL (NAIRA)  ...  NaN  NaN  \
# 3                    NaN                NaN             NaN  ...  NaN  NaN
# 4                    NaN                NaN             NaN  ...  NaN  NaN
# 5               351366.6      189196.679248   378393.358496  ...  NaN  NaN
# 6                    NaN                NaN             NaN  ...  NaN  NaN
# 7                    NaN                NaN             NaN  ...  NaN  NaN
# ..                   ...                ...             ...  ...  ...  ...
# 218                  NaN       42369.438592   169477.754368  ...  NaN  NaN
# 219                  NaN        35447.86496     354478.6496  ...  NaN  NaN
# 220                  NaN       225413.14128    225413.14128  ...  NaN  NaN
# 221                  NaN       225413.14128    225413.14128  ...  NaN  NaN
# 222                  NaN                NaN  7259957.942912  ...  NaN  NaN
#
#      NaN  NaN  NaN  NaN  NaN  NaN          CONTAINER_CODE  SUPPLIER_NAME
# 3    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 4    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 5    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 6    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 7    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# ..   ...  ...  ...  ...  ...  ...                     ...            ...
# 218  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 219  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 220  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 221  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
# 222  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)
#
# [220 rows x 24 columns]

# %%
# Supplier and item code list 
supplier = xl['DESCRIPTION'].fillna('re').to_list()
item_code = xl['CODE'].fillna('re').to_list()
quantity = xl['QUANTITY'].fillna('re').to_list()

# Check
supplier[:5], item_code[:5], quantity[:5]
# Out:
# (['re', 'ODF', 'ELECTRICAL TOWEL DRYER 3 BARS', 'TOTAL', 're'],
#  ['re', 're', 'OD 762 01', 're', 're'],
#  ['re', 're', 2, 're', 're'])

# %%
supplier_name = []
for i in range(len(supplier)):
    if supplier[i] != 're' and item_code[i] == 're' and quantity[i] == 're':
        supplier_name.append(supplier[i])
    elif supplier[i] == 're' and item_code[i] == 're'and quantity[i] == 're':
        supplier_name.append('delete_row')
    else:
        cont=supplier_name[-1].replace('~', '')
        supplier_name.append(f'{cont}~')

# %%
 # Checking values. 
supplier_name
# Out:
# ['delete_row',
#  'ODF',
#  'ODF~',
#  'TOTAL',
#  'delete_row',
#  'KASO',
#  'KASO~',
#  'KASO~',
#  'KASO~',
#  'TOTAL',
#  'delete_row',
#  'ARMADI ART',
#  'ARMADI ART~',
#  'TOTAL',
#  'delete_row',
#  'BOSSINI',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'TOTAL',
#  'PLASTIC PALLET',
#  'delete_row',
#  'delete_row',
#  'ZUCCHETTI. KOS',
#  'ZUCCHETTI. KOS~',
#  'INVOICE TOTAL',
#  'delete_row',
#  'SETTENCENTO',
#  'SETTENCENTO~',
#  'SETTENCENTO~',
#  'SETTENCENTO~',
#  'SETTENCENTO~',
#  'SETTENCENTO~',
#  'SETTENCENTO~',
#  'INVOICE TOTAL',
#  'delete_row',
#  'DURAVIT',
#  'DURAVIT~',
#  'DURAVIT~',
#  'INVOICE TOTAL',
#  'delete_row',
#  'HUPPE',
#  'HUPPE~',
#  'HUPPE~',
#  'HUPPE~',
#  'HUPPE~',
#  'INVOICE TOTAL',
#  'delete_row',
#  'INDA',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'delete_row',
#  'delete_row',
#  'GEBERIT',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'delete_row',
#  'delete_row',
#  'REMER',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'delete_row',
#  'delete_row',
#  'GEDY',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'INVOICE TOTAL',
#  'delete_row',
#  'POLIFORM',
#  'POLIFORM~',
#  'delete_row',
#  'delete_row',
#  'COLAVENE',
#  'COLAVENE~',
#  'COLAVENE~',
#  'COLAVENE~',
#  'COLAVENE~',
#  'COLAVENE~',
#  'COLAVENE~',
#  'COLAVENE~',
#  'COLAVENE~',
#  'delete_row',
#  'delete_row',
#  'COLOMBO',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'INVOICE TOTAL',
#  'delete_row',
#  'LAUFEN',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'LAUFEN~',
#  'delete_row']

# %%
# Defining supplier name
xl['SUPPLIER_NAME'] = supplier_name

xl
# Out:
#                                            DESCRIPTION           CODE  \
# 3                                                  NaN            NaN
# 4                                                  ODF            NaN
# 5                        ELECTRICAL TOWEL DRYER 3 BARS      OD 762 01
# 6                                                TOTAL            NaN
# 7                                                  NaN            NaN
# ..                                                 ...            ...
# 218  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 219  FLORA KIDS WORM MIRROR SEGMENT-BODY GREEN /32X...  LF 6161.2.472
# 220    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 221    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 222                                                NaN            NaN
#
#     QUANTITY  NaN UNIT PRICE IN EURO TOTAL PRICE IN EURO  UNIT PRICE IN NAIRA  \
# 3        NaN  NaN                NaN                  NaN                 NaN
# 4        NaN  NaN                NaN                  NaN                 NaN
# 5          2  NaN             450.47               900.94            175683.3
# 6        NaN  NaN                NaN               900.94                 NaN
# 7        NaN  NaN                NaN                  NaN                 NaN
# ..       ...  ...                ...                  ...                 ...
# 218        4  NaN             100.88               403.52                 NaN
# 219       10  NaN               84.4                  844                 NaN
# 220        1  NaN              536.7                536.7                 NaN
# 221        1  NaN              536.7                536.7                 NaN
# 222      NaN  NaN                NaN             17285.68                 NaN
#
#     TOTAL PRICE IN NAIRA UNIT PRICE (NAIRA)   TOTAL (NAIRA)  ...  NaN  NaN  \
# 3                    NaN                NaN             NaN  ...  NaN  NaN
# 4                    NaN                NaN             NaN  ...  NaN  NaN
# 5               351366.6      189196.679248   378393.358496  ...  NaN  NaN
# 6                    NaN                NaN             NaN  ...  NaN  NaN
# 7                    NaN                NaN             NaN  ...  NaN  NaN
# ..                   ...                ...             ...  ...  ...  ...
# 218                  NaN       42369.438592   169477.754368  ...  NaN  NaN
# 219                  NaN        35447.86496     354478.6496  ...  NaN  NaN
# 220                  NaN       225413.14128    225413.14128  ...  NaN  NaN
# 221                  NaN       225413.14128    225413.14128  ...  NaN  NaN
# 222                  NaN                NaN  7259957.942912  ...  NaN  NaN
#
#      NaN  NaN  NaN  NaN  NaN  NaN          CONTAINER_CODE  SUPPLIER_NAME
# 3    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)     delete_row
# 4    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)            ODF
# 5    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)           ODF~
# 6    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)          TOTAL
# 7    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)     delete_row
# ..   ...  ...  ...  ...  ...  ...                     ...            ...
# 218  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 219  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 220  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 221  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 222  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)     delete_row
#
# [220 rows x 24 columns]

# %%
# Rows to Delete.
delete_row = xl[xl['SUPPLIER_NAME'] == 'delete_row'].index.to_list()

# %%
# Drop rows. 
xl.drop(delete_row, axis = 0, inplace = True)

# Reset index. 
xl = xl.reset_index(drop = True)

# %%
xl
# Out:
#                                            DESCRIPTION           CODE  \
# 0                                                  ODF            NaN
# 1                        ELECTRICAL TOWEL DRYER 3 BARS      OD 762 01
# 2                                                TOTAL            NaN
# 3                                                 KASO            NaN
# 4    KASO E1-420 EUROSAFE(KEY LOCK/CUTTING/ADJUSTAB...         E1-420
# ..                                                 ...            ...
# 192  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 193  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 194  FLORA KIDS WORM MIRROR SEGMENT-BODY GREEN /32X...  LF 6161.2.472
# 195    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 196    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
#
#     QUANTITY  NaN UNIT PRICE IN EURO TOTAL PRICE IN EURO  UNIT PRICE IN NAIRA  \
# 0        NaN  NaN                NaN                  NaN                 NaN
# 1          2  NaN             450.47               900.94            175683.3
# 2        NaN  NaN                NaN               900.94                 NaN
# 3        NaN  NaN                NaN                  NaN                 NaN
# 4          1  NaN                900                  900            382695.3
# ..       ...  ...                ...                  ...                 ...
# 192        4  NaN             100.88               403.52                 NaN
# 193        4  NaN             100.88               403.52                 NaN
# 194       10  NaN               84.4                  844                 NaN
# 195        1  NaN              536.7                536.7                 NaN
# 196        1  NaN              536.7                536.7                 NaN
#
#     TOTAL PRICE IN NAIRA UNIT PRICE (NAIRA)  TOTAL (NAIRA)  ...  NaN  NaN  \
# 0                    NaN                NaN            NaN  ...  NaN  NaN
# 1               351366.6      189196.679248  378393.358496  ...  NaN  NaN
# 2                    NaN                NaN            NaN  ...  NaN  NaN
# 3                    NaN                NaN            NaN  ...  NaN  NaN
# 4               382695.3          377998.56      377998.56  ...  NaN  NaN
# ..                   ...                ...            ...  ...  ...  ...
# 192                  NaN       42369.438592  169477.754368  ...  NaN  NaN
# 193                  NaN       42369.438592  169477.754368  ...  NaN  NaN
# 194                  NaN        35447.86496    354478.6496  ...  NaN  NaN
# 195                  NaN       225413.14128   225413.14128  ...  NaN  NaN
# 196                  NaN       225413.14128   225413.14128  ...  NaN  NaN
#
#      NaN  NaN  NaN  NaN  NaN  NaN          CONTAINER_CODE  SUPPLIER_NAME
# 0    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)            ODF
# 1    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)           ODF~
# 2    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)          TOTAL
# 3    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)           KASO
# 4    NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)          KASO~
# ..   ...  ...  ...  ...  ...  ...                     ...            ...
# 192  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 193  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 194  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 195  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
# 196  NaN  NaN  NaN  NaN  NaN  NaN  CONTAINER 200(1 X40FT)        LAUFEN~
#
# [197 rows x 24 columns]

# %%
# Rows that aren't needed.
sup_del = xl[xl['SUPPLIER_NAME'] == xl['DESCRIPTION']].index

# %%
# Drop rows. 
xl.drop(sup_del, axis = 0, inplace = True)

# Reset index. 
xl = xl.reset_index(drop = True)

# %%
# Reordering columns 
xl = xl.loc[:, xl.columns[-2:].to_list() + xl.columns[:-2].to_list()]

# Checking columns order
xl.columns

# Veiwing result. 
xl
# Out:
#              CONTAINER_CODE SUPPLIER_NAME  \
# 0    CONTAINER 200(1 X40FT)          ODF~
# 1    CONTAINER 200(1 X40FT)         KASO~
# 2    CONTAINER 200(1 X40FT)         KASO~
# 3    CONTAINER 200(1 X40FT)         KASO~
# 4    CONTAINER 200(1 X40FT)   ARMADI ART~
# ..                      ...           ...
# 165  CONTAINER 200(1 X40FT)       LAUFEN~
# 166  CONTAINER 200(1 X40FT)       LAUFEN~
# 167  CONTAINER 200(1 X40FT)       LAUFEN~
# 168  CONTAINER 200(1 X40FT)       LAUFEN~
# 169  CONTAINER 200(1 X40FT)       LAUFEN~
#
#                                            DESCRIPTION           CODE  \
# 0                        ELECTRICAL TOWEL DRYER 3 BARS      OD 762 01
# 1    KASO E1-420 EUROSAFE(KEY LOCK/CUTTING/ADJUSTAB...         E1-420
# 2    KASO E-320 EUROSAFE (DOOR PANEL/KEY LOCK/ADJUS...        E-320SP
# 3    KASO E-330 EUROSAFE(DOOR PANEL/KEY LOCK/ADJUST...        E-330SP
# 4    ARMADI ART CRYSTALL 100 DELMAR CABINET AND GLA...    CRYSTAL 110
# ..                                                 ...            ...
# 165  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 166  CLEAR MIRROR WITH 2 INTERGRATED LED LIGHTS/60X...  JK 5572.5.144
# 167  FLORA KIDS WORM MIRROR SEGMENT-BODY GREEN /32X...  LF 6161.2.472
# 168    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
# 169    CASE PALACE VANITY 2 DRWER  FOR 1670.5/WHGLOSSY  LF 0160.2.475
#
#     QUANTITY  NaN UNIT PRICE IN EURO TOTAL PRICE IN EURO  UNIT PRICE IN NAIRA  \
# 0          2  NaN             450.47               900.94            175683.3
# 1          1  NaN                900                  900            382695.3
# 2          2  NaN               1170                 2340           497503.89
# 3          2  NaN             1387.5                 2775         589988.5875
# 4          1  NaN              774.5                774.5         329330.5665
# ..       ...  ...                ...                  ...                 ...
# 165        4  NaN             100.88               403.52                 NaN
# 166        4  NaN             100.88               403.52                 NaN
# 167       10  NaN               84.4                  844                 NaN
# 168        1  NaN              536.7                536.7                 NaN
# 169        1  NaN              536.7                536.7                 NaN
#
#     TOTAL PRICE IN NAIRA  ... INVOICE VALUE   NaN  NaN  NaN  NaN  NaN  NaN  \
# 0               351366.6  ...         900.94  NaN  NaN  NaN  NaN  NaN  NaN
# 1               382695.3  ...           6015  NaN  NaN  NaN  NaN  NaN  NaN
# 2              995007.78  ...            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3            1179977.175  ...            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4            329330.5665  ...          774.5  NaN  NaN  NaN  NaN  NaN  NaN
# ..                   ...  ...            ...  ...  ...  ...  ...  ...  ...
# 165                  NaN  ...            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 166                  NaN  ...            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 167                  NaN  ...            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 168                  NaN  ...            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 169                  NaN  ...            NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      NaN  NaN  NaN
# 0    NaN  NaN  NaN
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# ..   ...  ...  ...
# 165  NaN  NaN  NaN
# 166  NaN  NaN  NaN
# 167  NaN  NaN  NaN
# 168  NaN  NaN  NaN
# 169  NaN  NaN  NaN
#
# [170 rows x 24 columns]

# %%
xl.to_csv()
# Out:
# ',CONTAINER_CODE,SUPPLIER_NAME,CODE,DESCRIPTION,QUANTITY,CLIENT ,UNIT PRICE IN EURO,TOTAL PRICE IN EURO,UNIT PRICE IN NAIRA,TOTAL PRICE IN NAIRA,INVOICE NUMBER,INVOICE VALUE\r\n0,CONTAINER 367 - 369(3X40FT),DIQUIGIVANNI~,,DIQUIGIOVANNI WINDOWS FOR ALTONA,LOTS,THE ALTONA,85036.79,85036.79,47973505.078499995,47973505.0785,1443/1444,85036.79\r\n1,CONTAINER 367 - 369(3X40FT),DEDON~,DD 10003899,BABYLON PLANTER/COPPER,1,EMEKA DJIDOH,684,684,326268,326268,5344,684\r\n2,CONTAINER 367 - 369(3X40FT),LAUFEN~,JK 2137.0.000,DINO W/HUNG WC PAN WASHDOWN,80,STOCK,20.38,1630.3999999999999,11497.376999999999,919790.1599999999,1390221590,1630.3999999999999\r\n3,CONTAINER 367 - 369(3X40FT),SICIS~,,BALANCE WALL & POOL TILES FOR ALTONA,LOTS,THE ALTONA,,,,,,\r\n4,CONTAINER 367 - 369(3X40FT),DIQUIGIVANNI~,,DIQUIGIVANNI WINDOWS FOR ALTONA,LOTS,THE ALTONA,,,,,,\r\n'

# %%
columns
