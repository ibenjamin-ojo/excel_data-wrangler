# %%
# Import packages. 
import pandas as pd 
import os 

# Excel packages.
from openpyxl import Workbook as wb 
from openpyxl import load_workbook as lwb

# %%
# loaing packages. 
xl = pd.read_excel('extract.xlsx', sheet_name = '198',engine='openpyxl', na_values=['nan'])

# View file
xl
# Out:
#     Unnamed: 0               Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN                      NaN        NaN        NaN
# 1          NaN   CONTAINER 198(1 X40FT)        NaN        NaN
# 2         S/N               DESCRIPTION       CODE   QUANTITY
# 3          NaN                      NaN        NaN        NaN
# 4          NaN                     GEDY        NaN        NaN
# ..         ...                      ...        ...        ...
# 263         42  PANEL CASE 158X158X25CM     ZZ 150          2
# 264         43        CASE 250X160X50CM      ZZ 50          1
# 265         44        PALLET 71X75X30CM         Z1          3
# 266        NaN                      NaN        NaN        NaN
# 267        NaN              FOC DISPLAY        NaN        NaN
#
#              Unnamed: 4            Unnamed: 5           Unnamed: 6  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2    UNIT PRICE IN EURO  TOTAL PRICE IN EURO   UNIT PRICE IN NAIRA
# 3                   NaN                   NaN                  NaN
# 4                   NaN                   NaN                  NaN
# ..                  ...                   ...                  ...
# 263                 NaN                     0                    0
# 264                 NaN                     0                    0
# 265                 NaN                     0                    0
# 266                 NaN             22903.925                  NaN
# 267                 NaN             22903.925                    0
#
#                Unnamed: 7     Unnamed: 8      Unnamed: 9     Unnamed: 10  \
# 0                     NaN            NaN             NaN             NaN
# 1                429.1785            NaN             NaN             NaN
# 2    TOTAL PRICE IN NAIRA        CLIENT   INVOICE NUMBER  INVOICE VALUE
# 3                     NaN            NaN             NaN             NaN
# 4                     NaN            NaN             NaN             NaN
# ..                    ...            ...             ...             ...
# 263                     0  DISPLAY - RCA        INV 6/99             NaN
# 264                     0  DISPLAY - RCA        INV 6/99             NaN
# 265                     0  DISPLAY - RCA        INV 6/99             NaN
# 266        9829872.175613            NaN             NaN             NaN
# 267        9829872.175613            NaN             NaN             NaN
#
#      Unnamed: 11
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 263          NaN
# 264          NaN
# 265          NaN
# 266          NaN
# 267          NaN
#
# [268 rows x 12 columns]

# %%
code = xl.iloc[1, :].dropna().tolist()

code
# Out:
# ['CONTAINER 198(1 X40FT)', 429.17850000000004]

# %%
# Deleting rows
xl.drop([0,1], axis=0, inplace=True)

# checking file
xl
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 2         S/N                                         DESCRIPTION       CODE
# 3          NaN                                                NaN        NaN
# 4          NaN                                               GEDY        NaN
# 5            1  DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X...    GD 8400
# 6            2           EDERA FLOOR STANDING TOILET BRUSH HOLDER  GD ED3413
# ..         ...                                                ...        ...
# 263         42                            PANEL CASE 158X158X25CM     ZZ 150
# 264         43                                  CASE 250X160X50CM      ZZ 50
# 265         44                                  PALLET 71X75X30CM         Z1
# 266        NaN                                                NaN        NaN
# 267        NaN                                        FOC DISPLAY        NaN
#
#     Unnamed: 3          Unnamed: 4            Unnamed: 5           Unnamed: 6  \
# 2     QUANTITY  UNIT PRICE IN EURO  TOTAL PRICE IN EURO   UNIT PRICE IN NAIRA
# 3          NaN                 NaN                   NaN                  NaN
# 4          NaN                 NaN                   NaN                  NaN
# 5            5               20.22                 101.1           8677.98927
# 6            1               13.17                 13.17          5652.280845
# ..         ...                 ...                   ...                  ...
# 263          2                 NaN                     0                    0
# 264          1                 NaN                     0                    0
# 265          3                 NaN                     0                    0
# 266        NaN                 NaN             22903.925                  NaN
# 267        NaN                 NaN             22903.925                    0
#
#                Unnamed: 7     Unnamed: 8      Unnamed: 9     Unnamed: 10  \
# 2    TOTAL PRICE IN NAIRA        CLIENT   INVOICE NUMBER  INVOICE VALUE
# 3                     NaN            NaN             NaN             NaN
# 4                     NaN            NaN             NaN             NaN
# 5             43389.94635   INDEX BROOKS      INV 700243           101.1
# 6             5652.280845     PROF ABASS      INV 702972           42.31
# ..                    ...            ...             ...             ...
# 263                     0  DISPLAY - RCA        INV 6/99             NaN
# 264                     0  DISPLAY - RCA        INV 6/99             NaN
# 265                     0  DISPLAY - RCA        INV 6/99             NaN
# 266        9829872.175613            NaN             NaN             NaN
# 267        9829872.175613            NaN             NaN             NaN
#
#      Unnamed: 11
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# ..           ...
# 263          NaN
# 264          NaN
# 265          NaN
# 266          NaN
# 267          NaN
#
# [266 rows x 12 columns]

# %%
xl.iloc[0, :]
# Out:
# Unnamed: 0                     S/N
# Unnamed: 1              DESCRIPTION
# Unnamed: 2                     CODE
# Unnamed: 3                 QUANTITY
# Unnamed: 4       UNIT PRICE IN EURO
# Unnamed: 5     TOTAL PRICE IN EURO
# Unnamed: 6      UNIT PRICE IN NAIRA
# Unnamed: 7     TOTAL PRICE IN NAIRA
# Unnamed: 8                  CLIENT
# Unnamed: 9           INVOICE NUMBER
# Unnamed: 10          INVOICE VALUE
# Unnamed: 11                     NaN
# Name: 2, dtype: object

# %%
# Expected Columns. 
columns = ['S/N','DESCRIPTION','CODE','QUANTITY','UNIT PRICE IN EURO','TOTAL PRICE IN EURO ','EXCHANGE_RATE',
              'UNIT PRICE IN NAIRA','TOTAL PRICE IN NAIRA','CLIENT ','INVOICE NUMBER','INVOICE VALUE']

# checking to see the number of columns. 
if len(xl.columns) != len(columns):
    columns = xl.iloc[0,:]

# converting first row to header. 
xl.columns = columns

# Drop first row
xl.drop([2], axis= 0, inplace = True)
xl.reset_index()

# Checking values.
xl
# Out:
#      S/N                                        DESCRIPTION       CODE  \
# 3    NaN                                                NaN        NaN
# 4    NaN                                               GEDY        NaN
# 5      1  DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X...    GD 8400
# 6      2           EDERA FLOOR STANDING TOILET BRUSH HOLDER  GD ED3413
# 7      3                               EDERA SOAP DISPENSER  GD ED8113
# ..   ...                                                ...        ...
# 263   42                            PANEL CASE 158X158X25CM     ZZ 150
# 264   43                                  CASE 250X160X50CM      ZZ 50
# 265   44                                  PALLET 71X75X30CM         Z1
# 266  NaN                                                NaN        NaN
# 267  NaN                                        FOC DISPLAY        NaN
#
#     QUANTITY UNIT PRICE IN EURO TOTAL PRICE IN EURO  EXCHANGE_RATE  \
# 3        NaN                NaN                  NaN           NaN
# 4        NaN                NaN                  NaN           NaN
# 5          5              20.22                101.1    8677.98927
# 6          1              13.17                13.17   5652.280845
# 7          1              12.16                12.16    5218.81056
# ..       ...                ...                  ...           ...
# 263        2                NaN                    0             0
# 264        1                NaN                    0             0
# 265        3                NaN                    0             0
# 266      NaN                NaN            22903.925           NaN
# 267      NaN                NaN            22903.925             0
#
#     UNIT PRICE IN NAIRA TOTAL PRICE IN NAIRA     CLIENT  INVOICE NUMBER  \
# 3                   NaN                  NaN         NaN            NaN
# 4                   NaN                  NaN         NaN            NaN
# 5           43389.94635         INDEX BROOKS  INV 700243          101.1
# 6           5652.280845           PROF ABASS  INV 702972          42.31
# 7            5218.81056           PROF ABASS  INV 702972            NaN
# ..                  ...                  ...         ...            ...
# 263                   0        DISPLAY - RCA    INV 6/99            NaN
# 264                   0        DISPLAY - RCA    INV 6/99            NaN
# 265                   0        DISPLAY - RCA    INV 6/99            NaN
# 266      9829872.175613                  NaN         NaN            NaN
# 267      9829872.175613                  NaN         NaN            NaN
#
#      INVOICE VALUE
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# ..             ...
# 263            NaN
# 264            NaN
# 265            NaN
# 266            NaN
# 267            NaN
#
# [265 rows x 12 columns]

# %%
# Creating columns.
xl['SUPPLIER_NAME'] = ' '
xl['CONTAINER_CODE'] = code[0]

# Checking file
xl
# Out:
#      S/N                                        DESCRIPTION       CODE  \
# 3    NaN                                                NaN        NaN
# 4    NaN                                               GEDY        NaN
# 5      1  DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X...    GD 8400
# 6      2           EDERA FLOOR STANDING TOILET BRUSH HOLDER  GD ED3413
# 7      3                               EDERA SOAP DISPENSER  GD ED8113
# ..   ...                                                ...        ...
# 263   42                            PANEL CASE 158X158X25CM     ZZ 150
# 264   43                                  CASE 250X160X50CM      ZZ 50
# 265   44                                  PALLET 71X75X30CM         Z1
# 266  NaN                                                NaN        NaN
# 267  NaN                                        FOC DISPLAY        NaN
#
#     QUANTITY UNIT PRICE IN EURO TOTAL PRICE IN EURO  EXCHANGE_RATE  \
# 3        NaN                NaN                  NaN           NaN
# 4        NaN                NaN                  NaN           NaN
# 5          5              20.22                101.1    8677.98927
# 6          1              13.17                13.17   5652.280845
# 7          1              12.16                12.16    5218.81056
# ..       ...                ...                  ...           ...
# 263        2                NaN                    0             0
# 264        1                NaN                    0             0
# 265        3                NaN                    0             0
# 266      NaN                NaN            22903.925           NaN
# 267      NaN                NaN            22903.925             0
#
#     UNIT PRICE IN NAIRA TOTAL PRICE IN NAIRA     CLIENT  INVOICE NUMBER  \
# 3                   NaN                  NaN         NaN            NaN
# 4                   NaN                  NaN         NaN            NaN
# 5           43389.94635         INDEX BROOKS  INV 700243          101.1
# 6           5652.280845           PROF ABASS  INV 702972          42.31
# 7            5218.81056           PROF ABASS  INV 702972            NaN
# ..                  ...                  ...         ...            ...
# 263                   0        DISPLAY - RCA    INV 6/99            NaN
# 264                   0        DISPLAY - RCA    INV 6/99            NaN
# 265                   0        DISPLAY - RCA    INV 6/99            NaN
# 266      9829872.175613                  NaN         NaN            NaN
# 267      9829872.175613                  NaN         NaN            NaN
#
#      INVOICE VALUE SUPPLIER_NAME          CONTAINER_CODE
# 3              NaN                CONTAINER 198(1 X40FT)
# 4              NaN                CONTAINER 198(1 X40FT)
# 5              NaN                CONTAINER 198(1 X40FT)
# 6              NaN                CONTAINER 198(1 X40FT)
# 7              NaN                CONTAINER 198(1 X40FT)
# ..             ...           ...                     ...
# 263            NaN                CONTAINER 198(1 X40FT)
# 264            NaN                CONTAINER 198(1 X40FT)
# 265            NaN                CONTAINER 198(1 X40FT)
# 266            NaN                CONTAINER 198(1 X40FT)
# 267            NaN                CONTAINER 198(1 X40FT)
#
# [265 rows x 14 columns]

# %%
# # Reordering columns 
# xl = xl.loc[:, ['S/N', 'CONTAINER_CODE', 'SUPPLIER_NAME','DESCRIPTION', 'CODE', 'QUANTITY', 
#      'UNIT PRICE IN EURO','TOTAL PRICE IN EURO ', 'EXCHANGE_RATE', 'UNIT PRICE IN NAIRA',
#      'TOTAL PRICE IN NAIRA', 'CLIENT ', 'INVOICE NUMBER', 'INVOICE VALUE']]

# # Checking columns order
# xl.columns

# %%
# Drop columns that aren't needed
del xl[xl.columns[0]]

# Check 
xl
# Out:
#                                            DESCRIPTION       CODE QUANTITY  \
# 3                                                  NaN        NaN      NaN
# 4                                                 GEDY        NaN      NaN
# 5    DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X...    GD 8400        5
# 6             EDERA FLOOR STANDING TOILET BRUSH HOLDER  GD ED3413        1
# 7                                 EDERA SOAP DISPENSER  GD ED8113        1
# ..                                                 ...        ...      ...
# 263                            PANEL CASE 158X158X25CM     ZZ 150        2
# 264                                  CASE 250X160X50CM      ZZ 50        1
# 265                                  PALLET 71X75X30CM         Z1        3
# 266                                                NaN        NaN      NaN
# 267                                        FOC DISPLAY        NaN      NaN
#
#     UNIT PRICE IN EURO TOTAL PRICE IN EURO  EXCHANGE_RATE UNIT PRICE IN NAIRA  \
# 3                  NaN                  NaN           NaN                 NaN
# 4                  NaN                  NaN           NaN                 NaN
# 5                20.22                101.1    8677.98927         43389.94635
# 6                13.17                13.17   5652.280845         5652.280845
# 7                12.16                12.16    5218.81056          5218.81056
# ..                 ...                  ...           ...                 ...
# 263                NaN                    0             0                   0
# 264                NaN                    0             0                   0
# 265                NaN                    0             0                   0
# 266                NaN            22903.925           NaN      9829872.175613
# 267                NaN            22903.925             0      9829872.175613
#
#     TOTAL PRICE IN NAIRA     CLIENT  INVOICE NUMBER  INVOICE VALUE  \
# 3                    NaN         NaN            NaN            NaN
# 4                    NaN         NaN            NaN            NaN
# 5           INDEX BROOKS  INV 700243          101.1            NaN
# 6             PROF ABASS  INV 702972          42.31            NaN
# 7             PROF ABASS  INV 702972            NaN            NaN
# ..                   ...         ...            ...            ...
# 263        DISPLAY - RCA    INV 6/99            NaN            NaN
# 264        DISPLAY - RCA    INV 6/99            NaN            NaN
# 265        DISPLAY - RCA    INV 6/99            NaN            NaN
# 266                  NaN         NaN            NaN            NaN
# 267                  NaN         NaN            NaN            NaN
#
#     SUPPLIER_NAME          CONTAINER_CODE
# 3                  CONTAINER 198(1 X40FT)
# 4                  CONTAINER 198(1 X40FT)
# 5                  CONTAINER 198(1 X40FT)
# 6                  CONTAINER 198(1 X40FT)
# 7                  CONTAINER 198(1 X40FT)
# ..            ...                     ...
# 263                CONTAINER 198(1 X40FT)
# 264                CONTAINER 198(1 X40FT)
# 265                CONTAINER 198(1 X40FT)
# 266                CONTAINER 198(1 X40FT)
# 267                CONTAINER 198(1 X40FT)
#
# [265 rows x 13 columns]

# %%
# Supplier and item code list 
supplier = xl['DESCRIPTION'].fillna('re').to_list()
item_code = xl['CODE'].fillna('re').to_list()

# Check
supplier, item_code
# Out:
# (['re',
#   'GEDY',
#   'DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X65cm',
#   'EDERA FLOOR STANDING TOILET BRUSH HOLDER',
#   'EDERA SOAP DISPENSER',
#   'EDERA SPARE TOILET PAPER HOLDER ',
#   'EDERA TOWEL RING ',
#   'DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X65cm',
#   'EDERA TOOTHBRUSH HOLDER ',
#   'EDERA TOWEL HOLDER 60CM ',
#   'EDERA SPARE TOILET PAPER HOLDER ',
#   'FELCE TOWEL HOLDER 60CM ',
#   'GEDY FELCE PAPER HOLDER',
#   'FELCE TOILET BRUSH HOLDER',
#   're',
#   're',
#   'COLOMBO',
#   'BASIC SOAP DISH CROME - NARTUAR ACID GLASS',
#   'BASIC GLASS HOLDER NATURAL ACID GLASS',
#   'BASIC GLASS HOLDER NATURAL ACID GLASS',
#   'BASIC WALL HUNGING TOILET BRUSH',
#   'BASIC WALL HUNGING TOILET BRUSH',
#   'BASIC PAPER HOLDER',
#   'BASIC TOWEL HOLDER 60CM',
#   'BASIC DOUBLE TOWEL HOLDER 34.5CM',
#   'BASIC EXTRA TISSUE PAPER HOLDER',
#   'BASIC PAPER HOLDER WITH COVER',
#   'BASIC SOAP DISPENSER',
#   're',
#   're',
#   'INDA',
#   'NEW CLAIRE 87-89CM FIXED PANEL/CHROME/CLEAR GLASS',
#   'NEW CLAIRE 117-121CM SLIDING DOOR /CHROME/CLEAR GL',
#   'INDA NEW CLAIRE SLIDING DOOR, 121 -125CM /200CM HEIGHT ',
#   'INDA PRAIA DESIGN PIVOT DOOR WITH FIXED ELEMENT 4 NICHE,90CM/195CM',
#   'INDA NEW CLAIRE SLIDING DOOR, 159 -163CM /200CM HEIGHT ',
#   'INDA PRAIA CORNER ENTRY 90X90CM/195CM HEIGHT',
#   'INDA NEW CLAIRE SLIDING DOOR, 121 -125CM /200CM HEIGHT ',
#   'INDA PRAIA DESIGN PIVOT DOOR WITH FIXED ELEMENT FOR NICHE, 97 - 100CM/195CM HEIGHT ',
#   'INDA NEW CLAIRE SLIDING DOOR, 117 -121CM /200CM HEIGHT ',
#   'INDA NEW CLAIRE SLIDING DOOR, 161 -165CM /200CM HEIGHT ',
#   're',
#   're',
#   'BOSSINI',
#   'ZEN WATER SUPPLY FLANGE 1/2" M',
#   'OKI SHOWER HEAD',
#   'SUPPLY FLANGE WITH SHOWER HOOK/ROUND',
#   'SUPPLY FLANGE WITH SHOWER HOOK/SQUARE',
#   'DREAM RECTANGULAR SHOWER HEAD WITHOUT LIGHT500X400',
#   'OKI SHOWER HEAD 200MM WITH SHOWER ARM',
#   'AQUAVOLO ROTATING SHOWER HEAD  WITH 2 SPRAY',
#   're',
#   're',
#   'GEBERIT',
#   'ALPHA15 ACTUATOR PLATE DUAL FLUSH, WHITE ALPINE ',
#   'ALPHA50 ACTUATOR PLATE DUAL FLUSH, WHITE ALPINE',
#   'DELTA 21/WHITE ALPIN FLUSH ACTUATOR',
#   'WHITE ALPIN BOTTLE TRAP',
#   'CHROME BOTTLE TRAP',
#   'ALPHA01 ACTUATOR PLATE DUAL FLUSH, WHITE ALPINE',
#   'SIGMA 50 FLUSH ACTUATOR/ WHITE ALPIN',
#   'CHROME BOTTLE TRAP',
#   'CHROME BOTTLE TRAP',
#   'CHROME BOTTLE TRAP',
#   'WHITE ALPIN BOTTLE TRAP',
#   'SIGMA 50 FLUSH ACTUATOR/CUSTOMISED: WHITE + MATT CHROME ',
#   'CHROME BOTTLE TRAP',
#   'WHITE ALPIN BOTTLE TRAP',
#   'DRAIN COVER/SHINY CHROME FOR 150.670.00.1',
#   'UNIFLEX SHOWER TRAP/9CM OUTLET',
#   'CHROME BOTTLE TRAP',
#   'TRAPS FOR BIDET/WHITE ALPIN',
#   'SIGMA01 FLUSH ACTUATOR / WHITE ALPIN',
#   'ANGLE STOP VALVE FOR EXPOSED CISTERN',
#   're',
#   're',
#   'HANSGROHE',
#   'RAINDANCE E360 AIR 1JET OVERHEAD SHOWER WITH 100MM CEILING',
#   'CROMETTA 85 VARIO/PORTER C SET 1.60M',
#   'FOCUS E2 SHOWER MIXER WITH DIVERTER/ FINISH SET ONLY',
#   'AXOR STARCK BASIN MIXER',
#   'CROMA SELECT S 1JET PORTER SET .25M',
#   'CROMETTA 85 VARIO/PORTER C SET 1.60M',
#   'FOCUS E2 SHOWER MIXER WITH DIVERTER/ FINISH SET ONLY',
#   'TALIS BASIN MIXER 80 W/360 DEG SWIVEL SPOUT WITH POP UP WASTE/CHROME',
#   'LOGIS BASIN MIXER WITH WASTE 100',
#   'PURAVIDA BASIN MIXER/ HIGHRISER/WHITE CHROME',
#   'PURAVIDA BIDET MIXER/WHITE CHROME',
#   'CROMA SELECT S 1JET PORTER SET .25M',
#   'CROMA SELECT S 1JET SHOWER SET .65M',
#   'CROMA SELECT E VARIO SHOWER SET .65M WHITE CHROME',
#   'LOGIS 3 HOLE BASIN MIXER',
#   'LOGIS BIDET MIXER 100',
#   'LOGIS SINGLE LEVER BATH MIXER - EXPOSED',
#   'LOGIS SINGLE LEVER BATH MIXER WITH DIVERTER FOR IBOX',
#   'ANGLE VALVE 1/2X3/8',
#   'HANSGROHE RAINMAKER SELECT 460 2JET ',
#   'HG BASIC SET 4OVERHEAD SHOWER WITH CEILING CONNECT',
#   'CLASSIC HAND SHOWER BIDET WITH HOSE & SHOWER HOLDER/CHRM 1.25m',
#   'LOGIS HIGH TUBE BASIN MIXER 190',
#   'LOGIS SINGLE LEVER BATH MIXER WITH DIVERTER FOR IBOX',
#   'LOGIS LEVER SHOWER MIXER CONCEALED INSTALLATION',
#   'FOCUS E2 SHOWER MIXER WITH DIVERTER/ FINISH SET ONLY',
#   'METRIS SINGLE LEVER BASIN MIXER WITH POP UP WASTE/CHROME',
#   'METRIS WALL MOUNTED SHOWER MIXER CHR',
#   're',
#   're',
#   'REMER',
#   'C.P. BALL VALVE WITH FLANGE 1/2 3/8',
#   'CP BALL VALVE WITH FLANGE',
#   'CP BALL VALVE WITH FLANGE',
#   'FLEXIBLE HOSE 150CM',
#   'SQ3 WELLNSS ANTI LIMESTNE SELF CLEANING SHWER SET',
#   'SQ3 WELLNSS ANTI LIMESTNE SELF CLEANING SHOWER SET',
#   'HAND SHOWER BIDET WITH HOSE & SHOWER HOLDER/CHRM',
#   'EGIZIA BUILT IN STOPCOCK 3/4INCH',
#   'FLEXIBLE HOSE 150CM',
#   'ZAMAC BOTTLE TRAP WITH WASTE',
#   'CLASS LINE FREE STANDING BATH MIXER',
#   'WINNER BUILT IN SHOWE MIXER WITH DIVERTER',
#   'WINNER SINGLE LEVER BASIN MIXER',
#   're',
#   're',
#   'HUPPE',
#   'X1 FLEX 117-122CM SLIDING DOOR/SILVER/CLEAR GLASS',
#   'AURA ELEGANCE 146-150CM  SLIDING DOOR , 1PANEL WITH FIXED ELEMENT/MATT SILVER/CLEAR GLASS/RIGHT',
#   'STUDIO B CLEAR FRAMLES RECTANGULAR SWG DOOR160X120CMH220',
#   ' STUDIO B PURE FRAMELES RECTANGULAR SWG DOOR120X105CMH220',
#   'STUDIO B PURE FRAMELES RECTANGULAR SWG DOOR153X120CMH220',
#   'STUDIO B PURE FRAMELES RECTANGULAR SWG DOOR1200X300MM H220CM',
#   're',
#   're',
#   'DURAVIT',
#   'BAGNELLA WASHBOWL/48CM ',
#   'D-CODE WASHBASIN/65X50CM',
#   'PURAVIDA BATH TUB/FREE STANDING/200X100CM WITH COM',
#   'WASTE AND OVERFLOW QUADROVAL WITH BASE INLET',
#   'DURASTYLE MONOBLOC WC WITH VARIO CONNECTION',
#   'DURASTYLE DUAL FLUSH CISTERN BOTTOM LEFT SUPPLY',
#   'P3 COMFORT 105X50CM FURNITURE WASH BASIN ASYMMETRIC BOWL LEFT',
#   'L CUBE VANIT FOR BASIN 233310(555X1020X481mm)/FLANNEL GREY',
#   'DURAVIT PAIOVA WHIRLPOOLTUB 170x130cm',
#   'DURAVIT UV HYGIENE MANAGEMENT FOR WHIRLPOOL TUBS W',
#   'DURAVIT LED COLORED LIGHT WITH REMOTE CONTROL FOR ',
#   'HEAD REST',
#   'DURAVIT PANEL FOR CORNER RIGHT',
#   'NOISE REDUCTION SET FOR ACRYLIC BATH TUB',
#   'P3 COMFORT 105X50CM FURNITURE WASH BASIN ASYMMETRIC BOWL LEFT',
#   'L CUBE VANIT FOR BASIN 233310(102X481)/OLIV BROWN ',
#   'L CUBE VANIT FOR BASIN 233385(820MM)OLIVE BROWN HIGH GLOSS',
#   're',
#   're',
#   're',
#   'DYNAMOBEL',
#   'LEFT ARMREST FOR DIS CHAIR',
#   're',
#   'KALDEWEI',
#   'DUSCHPLAN SHOWER TRAY WITH ANTISLIP/ 90X120CM',
#   'SUPERPLAN XXL SHOWER TRAY (90X150CM)',
#   're',
#   're',
#   'SIEMATIC',
#   'SIEMATIC COUNTERTOP WITH STONE',
#   're',
#   'OIKOS',
#   'SYUNA FLUSH WITH WALL (1800X2400)',
#   'PROJECT RASOMURO INTERNO',
#   'EVOLUTION 3',
#   're',
#   're',
#   'JACUZZI',
#   'WHIRLPOOL TUB 170X70 WHITE',
#   're',
#   'BLANCO',
#   'S/S SINK NAYA WITH POP UP',
#   'S/S SINK NAYA BLANCOTIPO XL',
#   'CROCKERY BASKET NAYA ',
#   'CROCKERY BASKET FLEX TOP',
#   're',
#   're',
#   'NOBILIA',
#   'FIXED KITCHEN UNITS',
#   'REFRIGERATORS BUILDING-IN TYPE',
#   'RUBBISH BIN PLASTIC',
#   'RUBBISH BIN',
#   're',
#   're',
#   're',
#   'GUARDA (MGM)',
#   'MGM SQUARED MIRROR 30X30',
#   're',
#   're',
#   'POLIFORM',
#   'DISPLAY BOARD',
#   're',
#   're',
#   'LAUFEN/JIKA',
#   'CASE FOR LIVING CITY VANITY UNIT TWO DRAWER (1843.1/.2)/ANTHRACITE OAK',
#   'LIVINGCITY COUNTERTOPBASIN/RIGHT/ LOTUSGREY/100X46',
#   'CASE MIRROR WITH LIGHT/2 VERTICAL LIGHTS + SENSOR SWITCH/120X62CM',
#   'PALACE FLOOR BIDET',
#   'PRO BATH TUB PROJECT VERSION 170X70 WITH OUT PANEL',
#   'PALOMBA VANITY UNIT/4 DRAWERS(159X475CM)/FOR BASIN1480.9/WHITE',
#   'LB3 CLASSIC COUNTERTOP WASHBASIN/125CM/SINGLE HOLE',
#   'ALESSI ONE COUNTERTOP BASIN WITH SHELF RIGHT 120CM',
#   'PRO S WALLHUNG WC PAN, WASHDOWN MODEL',
#   'ALESSI ONE VANITY UNIT 99.4X32CM FOR WAHSBASIN WITH SHELF RIGHT 1497.3/GLOSSY WHITE',
#   'LYRA PLUS MIRROR WITH OUT LIGHT 75X60/CHERRY',
#   'LYRA PLUS MIRROR WITH OUT LIGHT 75X60/DARK OAK',
#   'SCREWS FOR WASHBASINS ASSEMBLY',
#   'SCREWS FOR WASHBASINS ASSEMBLY',
#   'MIO SOFT CLOSE ANTIBACTERIAL SEAT + COVER /CHROME ',
#   'CUBE VANITY WITH 2DRAWERS INCL WB 55X43CM WHITE',
#   'CUBE VANITY UNIT WITH WASHBASIN 65CM/WHITE',
#   're',
#   're',
#   'SICIS',
#   'FLOORING',
#   'COSMATI ACEDRES BL 29.8X29.8CM',
#   'MARBLE CALEDOS GOLD SPESSORE 1CM',
#   'RUG ZENONE 15X15',
#   'NEOGLASS MIX RANDOM C (246 VELVET 210.5 SATIN)',
#   'MARBLE CELOSIN BANDED TOBACCO',
#   'COSMARI MISTIS NR BORDER-NERO',
#   'FIBER ART VOLANS 139.6X235.6 CM GLUED ON ALUMINIUM',
#   'VETRITE FLAMES DORE 131X236 CM GLUED ON ALUMINIUM',
#   'GRAPHIC PANELS',
#   '30X30 CM AGATA',
#   '30X30 CM CALEIDIOS PLATINUM',
#   '30X30 CM WAVE PLATINUM',
#   '30X30 CM MIC RANDOM A',
#   '30X30 CM GLACIAL UNEVEN',
#   '30X30 CM CM ERIDANUS',
#   '30X30 CM FLO 9 C AMB',
#   '30X30 CM TRISTAN GREY DIAMOND COLL BOARD 45X100CM',
#   'DISPLAY BOARD TRISTAN GREY',
#   'DISPLAY BOARD AGRA TAUPE',
#   'DISPLAY BOARD CALEIDOS PLATINUM',
#   'DISPLAY BOARD AGATA',
#   'DISPLAY BOARD RAZLOM CLASSIC',
#   'DISPLAY BOARD TALISMAN GREY',
#   'DISPLAY BOARD KOBIDO GLACIAL',
#   'DISPLAY BOARD CLACIAL UNEVEN',
#   'DISPLAY BOARD CLACIAL WAVE PLATINUM',
#   'DISPLAY BOARD OLSON GREY',
#   'DISPLAY BOARD STRIPE 223',
#   'DISPLAY BOARD NGB 521 GLACIAL',
#   'DISPLAY BOARD CINNAMON NATURAL',
#   'DISPLAY BOARD ITEM 5_95-821 BASIC',
#   'DISPLAY BOARD PYRITE STRUCTURA',
#   'DISPLAY BOARD CELOSIN BANDED QUEEN',
#   'DISPLAY BOARD SCUBERT SILVER DIAMOND',
#   'DISPLAY BOARD VICTORAM WHC',
#   'DISPLAY BOARD TRIGO ICE PANEL',
#   'PIXEL GLASS MOSAIC DIAMOND SALICE GOLD 120X220CM GLUED ON ALUMINIUM',
#   'FLO 9 C - 99.6X219.6CM GLUED IN ALUMINIUM BOARD 70X40CM ',
#   'BOARD STRUCTURA ',
#   'BOARD BASIC',
#   'BOARDS BARMO',
#   'BOARD GLASS',
#   'PANEL CASE 158X158X25CM',
#   'CASE 250X160X50CM',
#   'PALLET 71X75X30CM',
#   're',
#   'FOC DISPLAY'],
#  ['re',
#   're',
#   'GD 8400',
#   'GD ED3413',
#   'GD ED8113',
#   'GD ED2413',
#   'GD ED7013',
#   'GD 8400',
#   'GD ED1013',
#   'GD ED2113/60',
#   'GD ED2413/02',
#   'GD FE2113/60',
#   'GD FE2913',
#   'GD FE3313',
#   're',
#   're',
#   're',
#   'CB 2701',
#   'CB 2702',
#   'CB 2702',
#   'CB 2707',
#   'CB 2707',
#   'CB 2708',
#   'CB 2711',
#   'CB 2712',
#   'CB 2790',
#   'CB 2791',
#   'CB 9332',
#   're',
#   're',
#   're',
#   'IN 5654',
#   'IN 5632',
#   'IN 5639',
#   'IN 1144',
#   'IN 5639',
#   'IN 1814',
#   'IN 5639',
#   'IN 1146',
#   'IN 5639',
#   'IN 5639',
#   're',
#   're',
#   're',
#   'BS V0022',
#   'BS H7040',
#   'BS C5400',
#   'BS C5500',
#   'BS H3839',
#   'BS 7H040',
#   'BS IX0555',
#   're',
#   're',
#   're',
#   'GB 115.045.11.1',
#   'GB 115.060.11.1',
#   'GB 115.125.11.1',
#   'GB 151.034.11.1',
#   'GB 151.034.21.1',
#   'GB 115.035.11.1',
#   'GB 115.788.11.5',
#   'GB 151.034.21.1',
#   'GB 151.034.21.1',
#   'GB 151.034.21.1',
#   'GB 151.034.11.1',
#   'GB 115.788.00.1',
#   'GB 151.034.21.1',
#   'GB 151.034.11.1',
#   'GB 150.275.21.1',
#   'GB 150.670.00.01',
#   'GB 151.034.21.1',
#   'GB 151.108.11.1',
#   'GB 115.770.11.5',
#   'GB 238.192.00.2',
#   're',
#   're',
#   're',
#   'HG 27371000',
#   'HG 27559000',
#   'HG 31945000',
#   'HG 10111000',
#   'HG 26420400',
#   'HG 27559000',
#   'HG 31945000',
#   'HG 32053000',
#   'HG 71100000',
#   'HG 15072400',
#   'HG 15270400',
#   'HG 26420400',
#   'HG 26564400',
#   'HG 26582400',
#   'HG 71133000',
#   'HG 71200000',
#   'HG 71400000',
#   'HG 71405000',
#   'HG 13901000',
#   'HG 24004400',
#   'HG 24010180',
#   'HG 32127000',
#   'HG 71090000',
#   'HG 71405000',
#   'HG 71605000',
#   'HG 31945000',
#   'HG 31080000',
#   'HG 31680000',
#   're',
#   're',
#   're',
#   'RM 128R1238',
#   'RM 128R1210',
#   'RM 128R1212',
#   'RM 333CN150',
#   'RM S9373S02',
#   'RM S093S02',
#   'RM 332332OL',
#   'RM 3234EG',
#   'RM 333CN150',
#   'RM 973Z114',
#   'RM L08',
#   'RM W09',
#   'RM W10',
#   're',
#   're',
#   're',
#   'HP 140402.069.321',
#   'HP 401507.087.321',
#   'HP BR0049.E05.321',
#   'HP BR0049.E05.321',
#   'HP BR0049.E05.321',
#   'HP BR0049.E05.321',
#   're',
#   're',
#   're',
#   'DV 0451480000',
#   'DV 23106500002',
#   'DV 760185000AS1000',
#   'DV 791229000001000',
#   'DV 2155090000',
#   'DV 0935100085',
#   'DV 2333100000',
#   'DV LC625108989',
#   'DV 760221000CE1000',
#   'DV 791884000000000',
#   'DV 791890000001000',
#   'DV 790001000000000',
#   'DV PA871108282',
#   'DV 791368000000000',
#   'DV 2333100000',
#   'DV LC625106161',
#   'DV LC624806161',
#   're',
#   're',
#   're',
#   're',
#   'DM 940116510149',
#   're',
#   're',
#   'KD 420-1',
#   'KD 439-1',
#   're',
#   're',
#   're',
#   'SM ASD3120-1F',
#   're',
#   're',
#   'OK 1608409',
#   'OK 1608414',
#   'OK 1608412',
#   're',
#   're',
#   're',
#   'JZ 9443776A',
#   're',
#   're',
#   'BL 00519442',
#   'BL 00511927',
#   'BL 00231693',
#   'BL 00514238 ',
#   're',
#   're',
#   're',
#   'NB 94034010',
#   'NB 84182159',
#   'NB 39269050',
#   'NB 73239900',
#   're',
#   're',
#   're',
#   're',
#   're',
#   're',
#   're',
#   're',
#   're',
#   're',
#   're',
#   're',
#   'LF 0128.2.548',
#   'LF 1843.2.134.08',
#   'LF 4726.6.144',
#   'LF 3270.1.302',
#   'LF 3695.0.000',
#   'LF 0745.4.180.220',
#   'LF 1068.8.104',
#   'LF 1497.3.104',
#   'LF 2096.1.000',
#   'LF 2452.0.631',
#   'JK 5320.1.316',
#   'JK 5320.1.318',
#   'JK 9034.9.000',
#   'JK 9034.9.000',
#   'JK 9271.2.300',
#   'JK 5361.2.300',
#   'JK 5360.1.300',
#   're',
#   're',
#   're',
#   're',
#   'CB DECORO',
#   'ST CALEIDOS GOLD',
#   'AB COMPOSIZ',
#   'NG MIX RANDOM C',
#   'ST CELOSIN GREEN',
#   'CB LISTIS NR BORDE',
#   'FI VOLANS',
#   'VE FLMES DORE',
#   're',
#   'ZZ DEPLIANT',
#   'ZZ DEPLIANT',
#   'ZZ DEPLIANT',
#   'ZZ DEPLIANT',
#   'ZZ DEPLIANT',
#   'ZZ DEPLIANT',
#   'ZZ DEPLIANT',
#   'ZZ DEPLIANT',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'EX BOARD',
#   'ZZ 150',
#   'ZZ 50',
#   'Z1',
#   're',
#   're'])

# %%
supplier_name = []
for i in range(len(supplier)):
    if supplier[i] != 're' and item_code[i] == 're':
        supplier_name.append(supplier[i])
    elif supplier[i] == 're' and item_code[i] == 're':
        supplier_name.append('delete_row')
    else:
        cont=supplier_name[-1].replace('~', '')
        supplier_name.append(f'{cont}~')

# %%
 # Checking values. 
supplier_name
# Out:
# ['delete_row',
#  'GEDY',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'GEDY~',
#  'delete_row',
#  'delete_row',
#  'COLOMBO',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'COLOMBO~',
#  'delete_row',
#  'delete_row',
#  'INDA',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'INDA~',
#  'delete_row',
#  'delete_row',
#  'BOSSINI',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'BOSSINI~',
#  'delete_row',
#  'delete_row',
#  'GEBERIT',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'GEBERIT~',
#  'delete_row',
#  'delete_row',
#  'HANSGROHE',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'HANSGROHE~',
#  'delete_row',
#  'delete_row',
#  'REMER',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'REMER~',
#  'delete_row',
#  'delete_row',
#  'HUPPE',
#  'HUPPE~',
#  'HUPPE~',
#  'HUPPE~',
#  'HUPPE~',
#  'HUPPE~',
#  'HUPPE~',
#  'delete_row',
#  'delete_row',
#  'DURAVIT',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'DURAVIT~',
#  'delete_row',
#  'delete_row',
#  'delete_row',
#  'DYNAMOBEL',
#  'DYNAMOBEL~',
#  'delete_row',
#  'KALDEWEI',
#  'KALDEWEI~',
#  'KALDEWEI~',
#  'delete_row',
#  'delete_row',
#  'SIEMATIC',
#  'SIEMATIC~',
#  'delete_row',
#  'OIKOS',
#  'OIKOS~',
#  'OIKOS~',
#  'OIKOS~',
#  'delete_row',
#  'delete_row',
#  'JACUZZI',
#  'JACUZZI~',
#  'delete_row',
#  'BLANCO',
#  'BLANCO~',
#  'BLANCO~',
#  'BLANCO~',
#  'BLANCO~',
#  'delete_row',
#  'delete_row',
#  'NOBILIA',
#  'NOBILIA~',
#  'NOBILIA~',
#  'NOBILIA~',
#  'NOBILIA~',
#  'delete_row',
#  'delete_row',
#  'delete_row',
#  'GUARDA (MGM)',
#  'MGM SQUARED MIRROR 30X30',
#  'delete_row',
#  'delete_row',
#  'POLIFORM',
#  'DISPLAY BOARD',
#  'delete_row',
#  'delete_row',
#  'LAUFEN/JIKA',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'LAUFEN/JIKA~',
#  'delete_row',
#  'delete_row',
#  'SICIS',
#  'FLOORING',
#  'FLOORING~',
#  'FLOORING~',
#  'FLOORING~',
#  'FLOORING~',
#  'FLOORING~',
#  'FLOORING~',
#  'FLOORING~',
#  'FLOORING~',
#  'GRAPHIC PANELS',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'GRAPHIC PANELS~',
#  'delete_row',
#  'FOC DISPLAY']

# %%
# Defining supplier name
xl['SUPPLIER_NAME'] = supplier_name

xl
# Out:
#                                            DESCRIPTION       CODE QUANTITY  \
# 3                                                  NaN        NaN      NaN
# 4                                                 GEDY        NaN      NaN
# 5    DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X...    GD 8400        5
# 6             EDERA FLOOR STANDING TOILET BRUSH HOLDER  GD ED3413        1
# 7                                 EDERA SOAP DISPENSER  GD ED8113        1
# ..                                                 ...        ...      ...
# 263                            PANEL CASE 158X158X25CM     ZZ 150        2
# 264                                  CASE 250X160X50CM      ZZ 50        1
# 265                                  PALLET 71X75X30CM         Z1        3
# 266                                                NaN        NaN      NaN
# 267                                        FOC DISPLAY        NaN      NaN
#
#     UNIT PRICE IN EURO TOTAL PRICE IN EURO  EXCHANGE_RATE UNIT PRICE IN NAIRA  \
# 3                  NaN                  NaN           NaN                 NaN
# 4                  NaN                  NaN           NaN                 NaN
# 5                20.22                101.1    8677.98927         43389.94635
# 6                13.17                13.17   5652.280845         5652.280845
# 7                12.16                12.16    5218.81056          5218.81056
# ..                 ...                  ...           ...                 ...
# 263                NaN                    0             0                   0
# 264                NaN                    0             0                   0
# 265                NaN                    0             0                   0
# 266                NaN            22903.925           NaN      9829872.175613
# 267                NaN            22903.925             0      9829872.175613
#
#     TOTAL PRICE IN NAIRA     CLIENT  INVOICE NUMBER  INVOICE VALUE  \
# 3                    NaN         NaN            NaN            NaN
# 4                    NaN         NaN            NaN            NaN
# 5           INDEX BROOKS  INV 700243          101.1            NaN
# 6             PROF ABASS  INV 702972          42.31            NaN
# 7             PROF ABASS  INV 702972            NaN            NaN
# ..                   ...         ...            ...            ...
# 263        DISPLAY - RCA    INV 6/99            NaN            NaN
# 264        DISPLAY - RCA    INV 6/99            NaN            NaN
# 265        DISPLAY - RCA    INV 6/99            NaN            NaN
# 266                  NaN         NaN            NaN            NaN
# 267                  NaN         NaN            NaN            NaN
#
#        SUPPLIER_NAME          CONTAINER_CODE
# 3         delete_row  CONTAINER 198(1 X40FT)
# 4               GEDY  CONTAINER 198(1 X40FT)
# 5              GEDY~  CONTAINER 198(1 X40FT)
# 6              GEDY~  CONTAINER 198(1 X40FT)
# 7              GEDY~  CONTAINER 198(1 X40FT)
# ..               ...                     ...
# 263  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 264  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 265  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 266       delete_row  CONTAINER 198(1 X40FT)
# 267      FOC DISPLAY  CONTAINER 198(1 X40FT)
#
# [265 rows x 13 columns]

# %%
# Rows to Delete.
delete_row = xl[xl['SUPPLIER_NAME'] == 'delete_row'].index.to_list()

# %%
# Drop rows. 
xl.drop(delete_row, axis = 0, inplace = True)

# Reset index. 
xl = xl.reset_index(drop = True)

# %%
xl
# Out:
#                                            DESCRIPTION       CODE QUANTITY  \
# 0                                                 GEDY        NaN      NaN
# 1    DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X...    GD 8400        5
# 2             EDERA FLOOR STANDING TOILET BRUSH HOLDER  GD ED3413        1
# 3                                 EDERA SOAP DISPENSER  GD ED8113        1
# 4                     EDERA SPARE TOILET PAPER HOLDER   GD ED2413        1
# ..                                                 ...        ...      ...
# 221                                        BOARD GLASS   EX BOARD       44
# 222                            PANEL CASE 158X158X25CM     ZZ 150        2
# 223                                  CASE 250X160X50CM      ZZ 50        1
# 224                                  PALLET 71X75X30CM         Z1        3
# 225                                        FOC DISPLAY        NaN      NaN
#
#     UNIT PRICE IN EURO TOTAL PRICE IN EURO  EXCHANGE_RATE UNIT PRICE IN NAIRA  \
# 0                  NaN                  NaN           NaN                 NaN
# 1                20.22                101.1    8677.98927         43389.94635
# 2                13.17                13.17   5652.280845         5652.280845
# 3                12.16                12.16    5218.81056          5218.81056
# 4                 8.49                 8.49   3643.725465         3643.725465
# ..                 ...                  ...           ...                 ...
# 221               17.5                  770    7510.62375          330467.445
# 222                NaN                    0             0                   0
# 223                NaN                    0             0                   0
# 224                NaN                    0             0                   0
# 225                NaN            22903.925             0      9829872.175613
#
#     TOTAL PRICE IN NAIRA     CLIENT  INVOICE NUMBER  INVOICE VALUE  \
# 0                    NaN         NaN            NaN            NaN
# 1           INDEX BROOKS  INV 700243          101.1            NaN
# 2             PROF ABASS  INV 702972          42.31            NaN
# 3             PROF ABASS  INV 702972            NaN            NaN
# 4             PROF ABASS  INV 702972            NaN            NaN
# ..                   ...         ...            ...            ...
# 221        DISPLAY - RCA    INV 6/99            NaN            NaN
# 222        DISPLAY - RCA    INV 6/99            NaN            NaN
# 223        DISPLAY - RCA    INV 6/99            NaN            NaN
# 224        DISPLAY - RCA    INV 6/99            NaN            NaN
# 225                  NaN         NaN            NaN            NaN
#
#        SUPPLIER_NAME          CONTAINER_CODE
# 0               GEDY  CONTAINER 198(1 X40FT)
# 1              GEDY~  CONTAINER 198(1 X40FT)
# 2              GEDY~  CONTAINER 198(1 X40FT)
# 3              GEDY~  CONTAINER 198(1 X40FT)
# 4              GEDY~  CONTAINER 198(1 X40FT)
# ..               ...                     ...
# 221  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 222  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 223  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 224  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 225      FOC DISPLAY  CONTAINER 198(1 X40FT)
#
# [226 rows x 13 columns]

# %%
# Rows that aren't needed.
sup_del = xl[xl['SUPPLIER_NAME'] == xl['DESCRIPTION']].index

# %%
# Drop rows. 
xl.drop(sup_del, axis = 0, inplace = True)

# Reset index. 
xl = xl.reset_index(drop = True)

# %%
# Veiwing result. 
xl
# Out:
#                                            DESCRIPTION       CODE QUANTITY  \
# 0    DAKOTA POLISHED EDGE MIRROR WITHOUT LIGHTS/50X...    GD 8400        5
# 1             EDERA FLOOR STANDING TOILET BRUSH HOLDER  GD ED3413        1
# 2                                 EDERA SOAP DISPENSER  GD ED8113        1
# 3                     EDERA SPARE TOILET PAPER HOLDER   GD ED2413        1
# 4                                    EDERA TOWEL RING   GD ED7013        1
# ..                                                 ...        ...      ...
# 196                                       BOARDS BARMO   EX BOARD        3
# 197                                        BOARD GLASS   EX BOARD       44
# 198                            PANEL CASE 158X158X25CM     ZZ 150        2
# 199                                  CASE 250X160X50CM      ZZ 50        1
# 200                                  PALLET 71X75X30CM         Z1        3
#
#     UNIT PRICE IN EURO TOTAL PRICE IN EURO  EXCHANGE_RATE UNIT PRICE IN NAIRA  \
# 0                20.22                101.1    8677.98927         43389.94635
# 1                13.17                13.17   5652.280845         5652.280845
# 2                12.16                12.16    5218.81056          5218.81056
# 3                 8.49                 8.49   3643.725465         3643.725465
# 4                 8.49                 8.49   3643.725465         3643.725465
# ..                 ...                  ...           ...                 ...
# 196                 35                  105    15021.2475          45063.7425
# 197               17.5                  770    7510.62375          330467.445
# 198                NaN                    0             0                   0
# 199                NaN                    0             0                   0
# 200                NaN                    0             0                   0
#
#     TOTAL PRICE IN NAIRA     CLIENT  INVOICE NUMBER  INVOICE VALUE  \
# 0           INDEX BROOKS  INV 700243          101.1            NaN
# 1             PROF ABASS  INV 702972          42.31            NaN
# 2             PROF ABASS  INV 702972            NaN            NaN
# 3             PROF ABASS  INV 702972            NaN            NaN
# 4             PROF ABASS  INV 702972            NaN            NaN
# ..                   ...         ...            ...            ...
# 196        DISPLAY - RCA    INV 6/99            NaN            NaN
# 197        DISPLAY - RCA    INV 6/99            NaN            NaN
# 198        DISPLAY - RCA    INV 6/99            NaN            NaN
# 199        DISPLAY - RCA    INV 6/99            NaN            NaN
# 200        DISPLAY - RCA    INV 6/99            NaN            NaN
#
#        SUPPLIER_NAME          CONTAINER_CODE
# 0              GEDY~  CONTAINER 198(1 X40FT)
# 1              GEDY~  CONTAINER 198(1 X40FT)
# 2              GEDY~  CONTAINER 198(1 X40FT)
# 3              GEDY~  CONTAINER 198(1 X40FT)
# 4              GEDY~  CONTAINER 198(1 X40FT)
# ..               ...                     ...
# 196  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 197  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 198  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 199  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
# 200  GRAPHIC PANELS~  CONTAINER 198(1 X40FT)
#
# [201 rows x 13 columns]
