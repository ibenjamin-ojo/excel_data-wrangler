# %%
# Import packages. 
import pandas as pd 
import os 

# Excel packages.
from openpyxl import Workbook as wb 
from openpyxl import load_workbook as lwb

# %%
# loaing packages. 
xl = pd.read_excel('extract_2022-11.xlsx', sheet_name = '367-369',engine='openpyxl', na_values=['nan'])

# View file
xl
# Out:
#    Unnamed: 0     Unnamed: 1                            Unnamed: 2 Unnamed: 3  \
# 0         NaN            NaN                                   NaN        NaN
# 1         NaN            NaN           CONTAINER 367 - 369(3X40FT)        NaN
# 2          SN           CODE                           DESCRIPTION   QUANTITY
# 3         NaN            NaN                          DIQUIGIVANNI        NaN
# 4         NaN            NaN      DIQUIGIOVANNI WINDOWS FOR ALTONA       LOTS
# 5         NaN            NaN                                   NaN        NaN
# 6         NaN            NaN                                   NaN        NaN
# 7         NaN            NaN                                 DEDON        NaN
# 8         NaN    DD 10003899                BABYLON PLANTER/COPPER          1
# 9         NaN            NaN                                   NaN        NaN
# 10        NaN            NaN                                   NaN        NaN
# 11        NaN            NaN                                   NaN        NaN
# 12        NaN            NaN                                LAUFEN        NaN
# 13        NaN  JK 2137.0.000           DINO W/HUNG WC PAN WASHDOWN         80
# 14        NaN            NaN                                   NaN        NaN
# 15        NaN            NaN                                   NaN        NaN
# 16        NaN            NaN                                   NaN        NaN
# 17        NaN            NaN                                 SICIS        NaN
# 18        NaN            NaN  BALANCE WALL & POOL TILES FOR ALTONA       LOTS
# 19        NaN            NaN                                   NaN        NaN
# 20        NaN            NaN                                   NaN        NaN
# 21        NaN            NaN                                   NaN        NaN
# 22        NaN            NaN                          DIQUIGIVANNI        NaN
# 23        NaN            NaN       DIQUIGIVANNI WINDOWS FOR ALTONA       LOTS
#
#       Unnamed: 4          Unnamed: 5           Unnamed: 6  \
# 0            NaN                 NaN                  NaN
# 1            NaN                 NaN                  NaN
# 2        CLIENT   UNIT PRICE IN EURO  TOTAL PRICE IN EURO
# 3            NaN                 NaN                  NaN
# 4     THE ALTONA            85036.79             85036.79
# 5            NaN                 NaN                  NaN
# 6            NaN                 NaN                  NaN
# 7            NaN                 NaN                  NaN
# 8   EMEKA DJIDOH                 684                  684
# 9            NaN                 NaN                  NaN
# 10           NaN                 NaN                  NaN
# 11           NaN                 NaN                  NaN
# 12           NaN                 NaN                  NaN
# 13         STOCK               20.38               1630.4
# 14           NaN                 NaN                  NaN
# 15           NaN                 NaN                  NaN
# 16           NaN                 NaN                  NaN
# 17           NaN                 NaN                  NaN
# 18    THE ALTONA                 NaN                  NaN
# 19           NaN                 NaN                  NaN
# 20           NaN                 NaN                  NaN
# 21           NaN                 NaN                  NaN
# 22           NaN                 NaN                  NaN
# 23    THE ALTONA                 NaN                  NaN
#
#                    EURO                564.15      Unnamed: 9    Unnamed: 10
# 0                   USD                   477             NaN            NaN
# 1                   NaN                   NaN             NaN            NaN
# 2   UNIT PRICE IN NAIRA  TOTAL PRICE IN NAIRA  INVOICE NUMBER  INVOICE VALUE
# 3                   NaN                   NaN             NaN            NaN
# 4         47973505.0785         47973505.0785       1443/1444       85036.79
# 5                   NaN                   NaN             NaN            NaN
# 6                   NaN                   NaN             NaN            NaN
# 7                   NaN                   NaN             NaN            NaN
# 8                326268                326268            5344            684
# 9                   NaN                   NaN             NaN            NaN
# 10                  NaN                   NaN             NaN            NaN
# 11                  NaN                   NaN             NaN            NaN
# 12                  NaN                   NaN             NaN            NaN
# 13            11497.377             919790.16      1390221590         1630.4
# 14                  NaN                   NaN             NaN            NaN
# 15                  NaN                   NaN             NaN            NaN
# 16                  NaN                   NaN             NaN            NaN
# 17                  NaN                   NaN             NaN            NaN
# 18                  NaN                   NaN             NaN            NaN
# 19                  NaN                   NaN             NaN            NaN
# 20                  NaN                   NaN             NaN            NaN
# 21                  NaN                   NaN             NaN            NaN
# 22                  NaN                   NaN             NaN            NaN
# 23                  NaN                   NaN             NaN            NaN

# %%
c_list = []

for i in range(4): 
    c = xl.iloc[i, :].dropna().to_list()
    c_list.append(c)

for j in range(len(c_list)): 
    if len(c_list[j])>=1 and c_list[j][0][:3] == 'CON':
        code = c_list[j][0]
        code_idx = j
        header_idx = j + 1
        break

code,code_idx,header_idx
# Out:
# ('CONTAINER 367 - 369(3X40FT)', 1, 2)

# %%
# Column Header. 
columns = xl.iloc[header_idx,:].to_list()
columns
# Out:
# ['SN',
#  'CODE',
#  'DESCRIPTION',
#  'QUANTITY',
#  'CLIENT ',
#  'UNIT PRICE IN EURO',
#  'TOTAL PRICE IN EURO',
#  'UNIT PRICE IN NAIRA',
#  'TOTAL PRICE IN NAIRA',
#  'INVOICE NUMBER',
#  'INVOICE VALUE']

# %%
# converting first row to header. 
xl.columns = columns

# Deleting rows
xl.drop([i for i in range(header_idx+1)], axis=0, inplace=True)

# Reset_index
xl.reset_index(drop = True)

# Checking values.
xl
# Out:
#      SN           CODE                           DESCRIPTION QUANTITY  \
# 3   NaN            NaN                          DIQUIGIVANNI      NaN
# 4   NaN            NaN      DIQUIGIOVANNI WINDOWS FOR ALTONA     LOTS
# 5   NaN            NaN                                   NaN      NaN
# 6   NaN            NaN                                   NaN      NaN
# 7   NaN            NaN                                 DEDON      NaN
# 8   NaN    DD 10003899                BABYLON PLANTER/COPPER        1
# 9   NaN            NaN                                   NaN      NaN
# 10  NaN            NaN                                   NaN      NaN
# 11  NaN            NaN                                   NaN      NaN
# 12  NaN            NaN                                LAUFEN      NaN
# 13  NaN  JK 2137.0.000           DINO W/HUNG WC PAN WASHDOWN       80
# 14  NaN            NaN                                   NaN      NaN
# 15  NaN            NaN                                   NaN      NaN
# 16  NaN            NaN                                   NaN      NaN
# 17  NaN            NaN                                 SICIS      NaN
# 18  NaN            NaN  BALANCE WALL & POOL TILES FOR ALTONA     LOTS
# 19  NaN            NaN                                   NaN      NaN
# 20  NaN            NaN                                   NaN      NaN
# 21  NaN            NaN                                   NaN      NaN
# 22  NaN            NaN                          DIQUIGIVANNI      NaN
# 23  NaN            NaN       DIQUIGIVANNI WINDOWS FOR ALTONA     LOTS
#
#          CLIENT  UNIT PRICE IN EURO TOTAL PRICE IN EURO UNIT PRICE IN NAIRA  \
# 3            NaN                NaN                 NaN                 NaN
# 4     THE ALTONA           85036.79            85036.79       47973505.0785
# 5            NaN                NaN                 NaN                 NaN
# 6            NaN                NaN                 NaN                 NaN
# 7            NaN                NaN                 NaN                 NaN
# 8   EMEKA DJIDOH                684                 684              326268
# 9            NaN                NaN                 NaN                 NaN
# 10           NaN                NaN                 NaN                 NaN
# 11           NaN                NaN                 NaN                 NaN
# 12           NaN                NaN                 NaN                 NaN
# 13         STOCK              20.38              1630.4           11497.377
# 14           NaN                NaN                 NaN                 NaN
# 15           NaN                NaN                 NaN                 NaN
# 16           NaN                NaN                 NaN                 NaN
# 17           NaN                NaN                 NaN                 NaN
# 18    THE ALTONA                NaN                 NaN                 NaN
# 19           NaN                NaN                 NaN                 NaN
# 20           NaN                NaN                 NaN                 NaN
# 21           NaN                NaN                 NaN                 NaN
# 22           NaN                NaN                 NaN                 NaN
# 23    THE ALTONA                NaN                 NaN                 NaN
#
#    TOTAL PRICE IN NAIRA INVOICE NUMBER INVOICE VALUE
# 3                   NaN            NaN           NaN
# 4         47973505.0785      1443/1444      85036.79
# 5                   NaN            NaN           NaN
# 6                   NaN            NaN           NaN
# 7                   NaN            NaN           NaN
# 8                326268           5344           684
# 9                   NaN            NaN           NaN
# 10                  NaN            NaN           NaN
# 11                  NaN            NaN           NaN
# 12                  NaN            NaN           NaN
# 13            919790.16     1390221590        1630.4
# 14                  NaN            NaN           NaN
# 15                  NaN            NaN           NaN
# 16                  NaN            NaN           NaN
# 17                  NaN            NaN           NaN
# 18                  NaN            NaN           NaN
# 19                  NaN            NaN           NaN
# 20                  NaN            NaN           NaN
# 21                  NaN            NaN           NaN
# 22                  NaN            NaN           NaN
# 23                  NaN            NaN           NaN

# %%
# Creating columns.
xl['CONTAINER_CODE'] = code
xl['SUPPLIER_NAME'] = ' '

# Checking file
xl
# Out:
#      SN           CODE                           DESCRIPTION QUANTITY  \
# 3   NaN            NaN                          DIQUIGIVANNI      NaN
# 4   NaN            NaN      DIQUIGIOVANNI WINDOWS FOR ALTONA     LOTS
# 5   NaN            NaN                                   NaN      NaN
# 6   NaN            NaN                                   NaN      NaN
# 7   NaN            NaN                                 DEDON      NaN
# 8   NaN    DD 10003899                BABYLON PLANTER/COPPER        1
# 9   NaN            NaN                                   NaN      NaN
# 10  NaN            NaN                                   NaN      NaN
# 11  NaN            NaN                                   NaN      NaN
# 12  NaN            NaN                                LAUFEN      NaN
# 13  NaN  JK 2137.0.000           DINO W/HUNG WC PAN WASHDOWN       80
# 14  NaN            NaN                                   NaN      NaN
# 15  NaN            NaN                                   NaN      NaN
# 16  NaN            NaN                                   NaN      NaN
# 17  NaN            NaN                                 SICIS      NaN
# 18  NaN            NaN  BALANCE WALL & POOL TILES FOR ALTONA     LOTS
# 19  NaN            NaN                                   NaN      NaN
# 20  NaN            NaN                                   NaN      NaN
# 21  NaN            NaN                                   NaN      NaN
# 22  NaN            NaN                          DIQUIGIVANNI      NaN
# 23  NaN            NaN       DIQUIGIVANNI WINDOWS FOR ALTONA     LOTS
#
#          CLIENT  UNIT PRICE IN EURO TOTAL PRICE IN EURO UNIT PRICE IN NAIRA  \
# 3            NaN                NaN                 NaN                 NaN
# 4     THE ALTONA           85036.79            85036.79       47973505.0785
# 5            NaN                NaN                 NaN                 NaN
# 6            NaN                NaN                 NaN                 NaN
# 7            NaN                NaN                 NaN                 NaN
# 8   EMEKA DJIDOH                684                 684              326268
# 9            NaN                NaN                 NaN                 NaN
# 10           NaN                NaN                 NaN                 NaN
# 11           NaN                NaN                 NaN                 NaN
# 12           NaN                NaN                 NaN                 NaN
# 13         STOCK              20.38              1630.4           11497.377
# 14           NaN                NaN                 NaN                 NaN
# 15           NaN                NaN                 NaN                 NaN
# 16           NaN                NaN                 NaN                 NaN
# 17           NaN                NaN                 NaN                 NaN
# 18    THE ALTONA                NaN                 NaN                 NaN
# 19           NaN                NaN                 NaN                 NaN
# 20           NaN                NaN                 NaN                 NaN
# 21           NaN                NaN                 NaN                 NaN
# 22           NaN                NaN                 NaN                 NaN
# 23    THE ALTONA                NaN                 NaN                 NaN
#
#    TOTAL PRICE IN NAIRA INVOICE NUMBER INVOICE VALUE  \
# 3                   NaN            NaN           NaN
# 4         47973505.0785      1443/1444      85036.79
# 5                   NaN            NaN           NaN
# 6                   NaN            NaN           NaN
# 7                   NaN            NaN           NaN
# 8                326268           5344           684
# 9                   NaN            NaN           NaN
# 10                  NaN            NaN           NaN
# 11                  NaN            NaN           NaN
# 12                  NaN            NaN           NaN
# 13            919790.16     1390221590        1630.4
# 14                  NaN            NaN           NaN
# 15                  NaN            NaN           NaN
# 16                  NaN            NaN           NaN
# 17                  NaN            NaN           NaN
# 18                  NaN            NaN           NaN
# 19                  NaN            NaN           NaN
# 20                  NaN            NaN           NaN
# 21                  NaN            NaN           NaN
# 22                  NaN            NaN           NaN
# 23                  NaN            NaN           NaN
#
#                  CONTAINER_CODE SUPPLIER_NAME
# 3   CONTAINER 367 - 369(3X40FT)
# 4   CONTAINER 367 - 369(3X40FT)
# 5   CONTAINER 367 - 369(3X40FT)
# 6   CONTAINER 367 - 369(3X40FT)
# 7   CONTAINER 367 - 369(3X40FT)
# 8   CONTAINER 367 - 369(3X40FT)
# 9   CONTAINER 367 - 369(3X40FT)
# 10  CONTAINER 367 - 369(3X40FT)
# 11  CONTAINER 367 - 369(3X40FT)
# 12  CONTAINER 367 - 369(3X40FT)
# 13  CONTAINER 367 - 369(3X40FT)
# 14  CONTAINER 367 - 369(3X40FT)
# 15  CONTAINER 367 - 369(3X40FT)
# 16  CONTAINER 367 - 369(3X40FT)
# 17  CONTAINER 367 - 369(3X40FT)
# 18  CONTAINER 367 - 369(3X40FT)
# 19  CONTAINER 367 - 369(3X40FT)
# 20  CONTAINER 367 - 369(3X40FT)
# 21  CONTAINER 367 - 369(3X40FT)
# 22  CONTAINER 367 - 369(3X40FT)
# 23  CONTAINER 367 - 369(3X40FT)

# %%
# # Reordering columns 
# xl = xl.loc[:, ['S/N', 'CONTAINER_CODE', 'SUPPLIER_NAME','DESCRIPTION', 'CODE', 'QUANTITY', 
#      'UNIT PRICE IN EURO','TOTAL PRICE IN EURO ', 'EXCHANGE_RATE', 'UNIT PRICE IN NAIRA',
#      'TOTAL PRICE IN NAIRA', 'CLIENT ', 'INVOICE NUMBER', 'INVOICE VALUE']]

# # Checking columns order
# xl.columns

# %%
# Drop columns that aren't needed
del xl[xl.columns[0]]

# Check 
xl
# Out:
#              CODE                           DESCRIPTION QUANTITY  \
# 3             NaN                          DIQUIGIVANNI      NaN
# 4             NaN      DIQUIGIOVANNI WINDOWS FOR ALTONA     LOTS
# 5             NaN                                   NaN      NaN
# 6             NaN                                   NaN      NaN
# 7             NaN                                 DEDON      NaN
# 8     DD 10003899                BABYLON PLANTER/COPPER        1
# 9             NaN                                   NaN      NaN
# 10            NaN                                   NaN      NaN
# 11            NaN                                   NaN      NaN
# 12            NaN                                LAUFEN      NaN
# 13  JK 2137.0.000           DINO W/HUNG WC PAN WASHDOWN       80
# 14            NaN                                   NaN      NaN
# 15            NaN                                   NaN      NaN
# 16            NaN                                   NaN      NaN
# 17            NaN                                 SICIS      NaN
# 18            NaN  BALANCE WALL & POOL TILES FOR ALTONA     LOTS
# 19            NaN                                   NaN      NaN
# 20            NaN                                   NaN      NaN
# 21            NaN                                   NaN      NaN
# 22            NaN                          DIQUIGIVANNI      NaN
# 23            NaN       DIQUIGIVANNI WINDOWS FOR ALTONA     LOTS
#
#          CLIENT  UNIT PRICE IN EURO TOTAL PRICE IN EURO UNIT PRICE IN NAIRA  \
# 3            NaN                NaN                 NaN                 NaN
# 4     THE ALTONA           85036.79            85036.79       47973505.0785
# 5            NaN                NaN                 NaN                 NaN
# 6            NaN                NaN                 NaN                 NaN
# 7            NaN                NaN                 NaN                 NaN
# 8   EMEKA DJIDOH                684                 684              326268
# 9            NaN                NaN                 NaN                 NaN
# 10           NaN                NaN                 NaN                 NaN
# 11           NaN                NaN                 NaN                 NaN
# 12           NaN                NaN                 NaN                 NaN
# 13         STOCK              20.38              1630.4           11497.377
# 14           NaN                NaN                 NaN                 NaN
# 15           NaN                NaN                 NaN                 NaN
# 16           NaN                NaN                 NaN                 NaN
# 17           NaN                NaN                 NaN                 NaN
# 18    THE ALTONA                NaN                 NaN                 NaN
# 19           NaN                NaN                 NaN                 NaN
# 20           NaN                NaN                 NaN                 NaN
# 21           NaN                NaN                 NaN                 NaN
# 22           NaN                NaN                 NaN                 NaN
# 23    THE ALTONA                NaN                 NaN                 NaN
#
#    TOTAL PRICE IN NAIRA INVOICE NUMBER INVOICE VALUE  \
# 3                   NaN            NaN           NaN
# 4         47973505.0785      1443/1444      85036.79
# 5                   NaN            NaN           NaN
# 6                   NaN            NaN           NaN
# 7                   NaN            NaN           NaN
# 8                326268           5344           684
# 9                   NaN            NaN           NaN
# 10                  NaN            NaN           NaN
# 11                  NaN            NaN           NaN
# 12                  NaN            NaN           NaN
# 13            919790.16     1390221590        1630.4
# 14                  NaN            NaN           NaN
# 15                  NaN            NaN           NaN
# 16                  NaN            NaN           NaN
# 17                  NaN            NaN           NaN
# 18                  NaN            NaN           NaN
# 19                  NaN            NaN           NaN
# 20                  NaN            NaN           NaN
# 21                  NaN            NaN           NaN
# 22                  NaN            NaN           NaN
# 23                  NaN            NaN           NaN
#
#                  CONTAINER_CODE SUPPLIER_NAME
# 3   CONTAINER 367 - 369(3X40FT)
# 4   CONTAINER 367 - 369(3X40FT)
# 5   CONTAINER 367 - 369(3X40FT)
# 6   CONTAINER 367 - 369(3X40FT)
# 7   CONTAINER 367 - 369(3X40FT)
# 8   CONTAINER 367 - 369(3X40FT)
# 9   CONTAINER 367 - 369(3X40FT)
# 10  CONTAINER 367 - 369(3X40FT)
# 11  CONTAINER 367 - 369(3X40FT)
# 12  CONTAINER 367 - 369(3X40FT)
# 13  CONTAINER 367 - 369(3X40FT)
# 14  CONTAINER 367 - 369(3X40FT)
# 15  CONTAINER 367 - 369(3X40FT)
# 16  CONTAINER 367 - 369(3X40FT)
# 17  CONTAINER 367 - 369(3X40FT)
# 18  CONTAINER 367 - 369(3X40FT)
# 19  CONTAINER 367 - 369(3X40FT)
# 20  CONTAINER 367 - 369(3X40FT)
# 21  CONTAINER 367 - 369(3X40FT)
# 22  CONTAINER 367 - 369(3X40FT)
# 23  CONTAINER 367 - 369(3X40FT)

# %%
# Supplier and item code list 
supplier = xl['DESCRIPTION'].fillna('re').to_list()
item_code = xl['CODE'].fillna('re').to_list()
quantity = xl['QUANTITY'].fillna('re').to_list()

# Check
supplier[:5], item_code[:5], quantity[:5]
# Out:
# (['DIQUIGIVANNI', 'DIQUIGIOVANNI WINDOWS FOR ALTONA', 're', 're', 'DEDON'],
#  ['re', 're', 're', 're', 're'],
#  ['re', 'LOTS', 're', 're', 're'])

# %%
supplier_name = []
for i in range(len(supplier)):
    if supplier[i] != 're' and item_code[i] == 're' and quantity[i] == 're':
        supplier_name.append(supplier[i])
    elif supplier[i] == 're' and item_code[i] == 're'and quantity[i] == 're':
        supplier_name.append('delete_row')
    else:
        cont=supplier_name[-1].replace('~', '')
        supplier_name.append(f'{cont}~')

# %%
 # Checking values. 
supplier_name
# Out:
# ['DIQUIGIVANNI',
#  'DIQUIGIVANNI~',
#  'delete_row',
#  'delete_row',
#  'DEDON',
#  'DEDON~',
#  'delete_row',
#  'delete_row',
#  'delete_row',
#  'LAUFEN',
#  'LAUFEN~',
#  'delete_row',
#  'delete_row',
#  'delete_row',
#  'SICIS',
#  'SICIS~',
#  'delete_row',
#  'delete_row',
#  'delete_row',
#  'DIQUIGIVANNI',
#  'DIQUIGIVANNI~']

# %%
# Defining supplier name
xl['SUPPLIER_NAME'] = supplier_name

xl
# Out:
#              CODE                           DESCRIPTION QUANTITY  \
# 3             NaN                          DIQUIGIVANNI      NaN
# 4             NaN      DIQUIGIOVANNI WINDOWS FOR ALTONA     LOTS
# 5             NaN                                   NaN      NaN
# 6             NaN                                   NaN      NaN
# 7             NaN                                 DEDON      NaN
# 8     DD 10003899                BABYLON PLANTER/COPPER        1
# 9             NaN                                   NaN      NaN
# 10            NaN                                   NaN      NaN
# 11            NaN                                   NaN      NaN
# 12            NaN                                LAUFEN      NaN
# 13  JK 2137.0.000           DINO W/HUNG WC PAN WASHDOWN       80
# 14            NaN                                   NaN      NaN
# 15            NaN                                   NaN      NaN
# 16            NaN                                   NaN      NaN
# 17            NaN                                 SICIS      NaN
# 18            NaN  BALANCE WALL & POOL TILES FOR ALTONA     LOTS
# 19            NaN                                   NaN      NaN
# 20            NaN                                   NaN      NaN
# 21            NaN                                   NaN      NaN
# 22            NaN                          DIQUIGIVANNI      NaN
# 23            NaN       DIQUIGIVANNI WINDOWS FOR ALTONA     LOTS
#
#          CLIENT  UNIT PRICE IN EURO TOTAL PRICE IN EURO UNIT PRICE IN NAIRA  \
# 3            NaN                NaN                 NaN                 NaN
# 4     THE ALTONA           85036.79            85036.79       47973505.0785
# 5            NaN                NaN                 NaN                 NaN
# 6            NaN                NaN                 NaN                 NaN
# 7            NaN                NaN                 NaN                 NaN
# 8   EMEKA DJIDOH                684                 684              326268
# 9            NaN                NaN                 NaN                 NaN
# 10           NaN                NaN                 NaN                 NaN
# 11           NaN                NaN                 NaN                 NaN
# 12           NaN                NaN                 NaN                 NaN
# 13         STOCK              20.38              1630.4           11497.377
# 14           NaN                NaN                 NaN                 NaN
# 15           NaN                NaN                 NaN                 NaN
# 16           NaN                NaN                 NaN                 NaN
# 17           NaN                NaN                 NaN                 NaN
# 18    THE ALTONA                NaN                 NaN                 NaN
# 19           NaN                NaN                 NaN                 NaN
# 20           NaN                NaN                 NaN                 NaN
# 21           NaN                NaN                 NaN                 NaN
# 22           NaN                NaN                 NaN                 NaN
# 23    THE ALTONA                NaN                 NaN                 NaN
#
#    TOTAL PRICE IN NAIRA INVOICE NUMBER INVOICE VALUE  \
# 3                   NaN            NaN           NaN
# 4         47973505.0785      1443/1444      85036.79
# 5                   NaN            NaN           NaN
# 6                   NaN            NaN           NaN
# 7                   NaN            NaN           NaN
# 8                326268           5344           684
# 9                   NaN            NaN           NaN
# 10                  NaN            NaN           NaN
# 11                  NaN            NaN           NaN
# 12                  NaN            NaN           NaN
# 13            919790.16     1390221590        1630.4
# 14                  NaN            NaN           NaN
# 15                  NaN            NaN           NaN
# 16                  NaN            NaN           NaN
# 17                  NaN            NaN           NaN
# 18                  NaN            NaN           NaN
# 19                  NaN            NaN           NaN
# 20                  NaN            NaN           NaN
# 21                  NaN            NaN           NaN
# 22                  NaN            NaN           NaN
# 23                  NaN            NaN           NaN
#
#                  CONTAINER_CODE  SUPPLIER_NAME
# 3   CONTAINER 367 - 369(3X40FT)   DIQUIGIVANNI
# 4   CONTAINER 367 - 369(3X40FT)  DIQUIGIVANNI~
# 5   CONTAINER 367 - 369(3X40FT)     delete_row
# 6   CONTAINER 367 - 369(3X40FT)     delete_row
# 7   CONTAINER 367 - 369(3X40FT)          DEDON
# 8   CONTAINER 367 - 369(3X40FT)         DEDON~
# 9   CONTAINER 367 - 369(3X40FT)     delete_row
# 10  CONTAINER 367 - 369(3X40FT)     delete_row
# 11  CONTAINER 367 - 369(3X40FT)     delete_row
# 12  CONTAINER 367 - 369(3X40FT)         LAUFEN
# 13  CONTAINER 367 - 369(3X40FT)        LAUFEN~
# 14  CONTAINER 367 - 369(3X40FT)     delete_row
# 15  CONTAINER 367 - 369(3X40FT)     delete_row
# 16  CONTAINER 367 - 369(3X40FT)     delete_row
# 17  CONTAINER 367 - 369(3X40FT)          SICIS
# 18  CONTAINER 367 - 369(3X40FT)         SICIS~
# 19  CONTAINER 367 - 369(3X40FT)     delete_row
# 20  CONTAINER 367 - 369(3X40FT)     delete_row
# 21  CONTAINER 367 - 369(3X40FT)     delete_row
# 22  CONTAINER 367 - 369(3X40FT)   DIQUIGIVANNI
# 23  CONTAINER 367 - 369(3X40FT)  DIQUIGIVANNI~

# %%
# Rows to Delete.
delete_row = xl[xl['SUPPLIER_NAME'] == 'delete_row'].index.to_list()

# %%
# Drop rows. 
xl.drop(delete_row, axis = 0, inplace = True)

# Reset index. 
xl = xl.reset_index(drop = True)

# %%
xl
# Out:
#             CODE                           DESCRIPTION QUANTITY       CLIENT   \
# 0            NaN                          DIQUIGIVANNI      NaN           NaN
# 1            NaN      DIQUIGIOVANNI WINDOWS FOR ALTONA     LOTS    THE ALTONA
# 2            NaN                                 DEDON      NaN           NaN
# 3    DD 10003899                BABYLON PLANTER/COPPER        1  EMEKA DJIDOH
# 4            NaN                                LAUFEN      NaN           NaN
# 5  JK 2137.0.000           DINO W/HUNG WC PAN WASHDOWN       80         STOCK
# 6            NaN                                 SICIS      NaN           NaN
# 7            NaN  BALANCE WALL & POOL TILES FOR ALTONA     LOTS    THE ALTONA
# 8            NaN                          DIQUIGIVANNI      NaN           NaN
# 9            NaN       DIQUIGIVANNI WINDOWS FOR ALTONA     LOTS    THE ALTONA
#
#   UNIT PRICE IN EURO TOTAL PRICE IN EURO UNIT PRICE IN NAIRA  \
# 0                NaN                 NaN                 NaN
# 1           85036.79            85036.79       47973505.0785
# 2                NaN                 NaN                 NaN
# 3                684                 684              326268
# 4                NaN                 NaN                 NaN
# 5              20.38              1630.4           11497.377
# 6                NaN                 NaN                 NaN
# 7                NaN                 NaN                 NaN
# 8                NaN                 NaN                 NaN
# 9                NaN                 NaN                 NaN
#
#   TOTAL PRICE IN NAIRA INVOICE NUMBER INVOICE VALUE  \
# 0                  NaN            NaN           NaN
# 1        47973505.0785      1443/1444      85036.79
# 2                  NaN            NaN           NaN
# 3               326268           5344           684
# 4                  NaN            NaN           NaN
# 5            919790.16     1390221590        1630.4
# 6                  NaN            NaN           NaN
# 7                  NaN            NaN           NaN
# 8                  NaN            NaN           NaN
# 9                  NaN            NaN           NaN
#
#                 CONTAINER_CODE  SUPPLIER_NAME
# 0  CONTAINER 367 - 369(3X40FT)   DIQUIGIVANNI
# 1  CONTAINER 367 - 369(3X40FT)  DIQUIGIVANNI~
# 2  CONTAINER 367 - 369(3X40FT)          DEDON
# 3  CONTAINER 367 - 369(3X40FT)         DEDON~
# 4  CONTAINER 367 - 369(3X40FT)         LAUFEN
# 5  CONTAINER 367 - 369(3X40FT)        LAUFEN~
# 6  CONTAINER 367 - 369(3X40FT)          SICIS
# 7  CONTAINER 367 - 369(3X40FT)         SICIS~
# 8  CONTAINER 367 - 369(3X40FT)   DIQUIGIVANNI
# 9  CONTAINER 367 - 369(3X40FT)  DIQUIGIVANNI~

# %%
# Rows that aren't needed.
sup_del = xl[xl['SUPPLIER_NAME'] == xl['DESCRIPTION']].index

# %%
# Drop rows. 
xl.drop(sup_del, axis = 0, inplace = True)

# Reset index. 
xl = xl.reset_index(drop = True)

# %%
# Reordering columns 
xl = xl.loc[:, xl.columns[-2:].to_list() + xl.columns[:-2].to_list()]

# Checking columns order
xl.columns

# Veiwing result. 
xl
# Out:
#                 CONTAINER_CODE  SUPPLIER_NAME           CODE  \
# 0  CONTAINER 367 - 369(3X40FT)  DIQUIGIVANNI~            NaN
# 1  CONTAINER 367 - 369(3X40FT)         DEDON~    DD 10003899
# 2  CONTAINER 367 - 369(3X40FT)        LAUFEN~  JK 2137.0.000
# 3  CONTAINER 367 - 369(3X40FT)         SICIS~            NaN
# 4  CONTAINER 367 - 369(3X40FT)  DIQUIGIVANNI~            NaN
#
#                             DESCRIPTION QUANTITY       CLIENT   \
# 0      DIQUIGIOVANNI WINDOWS FOR ALTONA     LOTS    THE ALTONA
# 1                BABYLON PLANTER/COPPER        1  EMEKA DJIDOH
# 2           DINO W/HUNG WC PAN WASHDOWN       80         STOCK
# 3  BALANCE WALL & POOL TILES FOR ALTONA     LOTS    THE ALTONA
# 4       DIQUIGIVANNI WINDOWS FOR ALTONA     LOTS    THE ALTONA
#
#   UNIT PRICE IN EURO TOTAL PRICE IN EURO UNIT PRICE IN NAIRA  \
# 0           85036.79            85036.79       47973505.0785
# 1                684                 684              326268
# 2              20.38              1630.4           11497.377
# 3                NaN                 NaN                 NaN
# 4                NaN                 NaN                 NaN
#
#   TOTAL PRICE IN NAIRA INVOICE NUMBER INVOICE VALUE
# 0        47973505.0785      1443/1444      85036.79
# 1               326268           5344           684
# 2            919790.16     1390221590        1630.4
# 3                  NaN            NaN           NaN
# 4                  NaN            NaN           NaN

# %%
xl.to_csv()
# Out:
# ',CONTAINER_CODE,SUPPLIER_NAME,CODE,DESCRIPTION,QUANTITY,CLIENT ,UNIT PRICE IN EURO,TOTAL PRICE IN EURO,UNIT PRICE IN NAIRA,TOTAL PRICE IN NAIRA,INVOICE NUMBER,INVOICE VALUE\r\n0,CONTAINER 367 - 369(3X40FT),DIQUIGIVANNI~,,DIQUIGIOVANNI WINDOWS FOR ALTONA,LOTS,THE ALTONA,85036.79,85036.79,47973505.078499995,47973505.0785,1443/1444,85036.79\r\n1,CONTAINER 367 - 369(3X40FT),DEDON~,DD 10003899,BABYLON PLANTER/COPPER,1,EMEKA DJIDOH,684,684,326268,326268,5344,684\r\n2,CONTAINER 367 - 369(3X40FT),LAUFEN~,JK 2137.0.000,DINO W/HUNG WC PAN WASHDOWN,80,STOCK,20.38,1630.3999999999999,11497.376999999999,919790.1599999999,1390221590,1630.3999999999999\r\n3,CONTAINER 367 - 369(3X40FT),SICIS~,,BALANCE WALL & POOL TILES FOR ALTONA,LOTS,THE ALTONA,,,,,,\r\n4,CONTAINER 367 - 369(3X40FT),DIQUIGIVANNI~,,DIQUIGIVANNI WINDOWS FOR ALTONA,LOTS,THE ALTONA,,,,,,\r\n'

# %%
columns
